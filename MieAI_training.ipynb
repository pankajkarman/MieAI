# %%
# %load_ext autotime
# Out:
# time: 139 µs (started: 2023-08-19 21:33:10 +02:00)

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# time: 485 µs (started: 2023-08-19 21:33:10 +02:00)

# %%
import json
# from mei import Size_Distribution_Optics
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# Out:
# time: 1.5 s (started: 2023-08-19 21:33:10 +02:00)

# %%
import glob
import dask.dataframe as dd
# Out:
# time: 763 ms (started: 2023-08-19 21:33:12 +02:00)

# %%
import sklearn
from sklearn.preprocessing import MinMaxScaler, PowerTransformer, QuantileTransformer
from sklearn.metrics import r2_score 
import joblib
# Out:
# time: 815 ms (started: 2023-08-19 21:33:12 +02:00)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Activation

from tensorflow.keras.callbacks import ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau, EarlyStopping
# Out:
# 2023-08-19 21:33:13.653274: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-19 21:33:13.980874: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-19 21:33:13.980900: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-08-19 21:33:15.791888: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-08-19 21:33:15.792331: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-08-19 21:33:15.792340: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# time: 4.81 s (started: 2023-08-19 21:33:13 +02:00)

# %%
# from kerastuner.tuners import RandomSearch
# Out:
# time: 180 µs (started: 2023-08-19 21:33:18 +02:00)

# %%
def normalize(df):
    return (df - df.mean()) / df.std()

def normalize1(df):    
    mx = df.max()
    mn = df.min()
    
    mx['SSA'] = 1.0
    mx['Asym'] = 1.0
    
    mn['SSA'] = 0.0
    mn['Asym'] = 0.0
    
    new = (df - mn) / (mx - mn)    
    return new


def load_opt(filename):
    with open(filename, "r") as fp:
        data = json.load(fp)
    return data


def create_model(
    input_size,
    output_size,
    hidden=[14, 16, 5, 10],
    dropout=[0.1, 0.3, 0.3, 0],
    activation=["relu", "tanh", "tanh", "tanh"],
    loss="mean_absolute_error",
    optimizer="adam",
    metrics=["mean_squared_error"],
):
    input_shape = (input_size,)
    print(f"Input shape: {input_shape}")

    # Create the model
    model = Sequential()
    model.add(
        Dense(
            hidden[0],
            input_shape=input_shape,
            activation=activation[0],
            name="hidden_layer_1",
            use_bias=True,
        ),
    )
    model.add(Dropout(dropout[0]))

    if len(hidden) > 1:
        for i, (ly , act, drp) in enumerate(zip(hidden[1:], activation[1:], dropout[1:])):
            model.add(
                Dense(
                    ly,
                    activation=act,
                    name="hidden_layer_%s" % (i + 2),
                    use_bias=True,
                )
            )
            model.add(Dropout(drp))
    # model.add(Dense(output_size, activation="sigmoid", name="output_layer"))
    model.add(Dense(output_size, name="output_layer"))

    # Configure the model and start training
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    print(model.summary())
    return model
# Out:
# time: 2.46 ms (started: 2023-08-19 21:33:18 +02:00)

# %%
columns = ['Extinction', 'Scattering', 'SSA', 'Asym', 'coating', 'core_dia', 'n_core', 'k_core', 'n_shell', 'k_shell', 'density', 'lambda']
df1 = pd.read_csv('/work/bb1070/b382177/mie/icon/12-05-2023/mie_x1.csv', index_col=0).sort_index().sort_index().iloc[:-1224, :]
df2 = pd.read_csv('/work/bb1070/b382177/mie/icon/12-05-2023/mie_x2.csv', index_col=0).sort_index().sort_index().iloc[:-1224, :]
df = pd.concat([df1, df2], axis=0).reset_index()
df = df[columns].dropna().astype('float')
df['x'] = np.pi * df['core_dia'] / df['lambda']
df
# Out:
#         Extinction  Scattering       SSA      Asym  coating  core_dia  \
# 0         2.371424    1.497649  0.631540  0.898342      0.0    4000.0
# 1         2.203139    1.330449  0.603888  0.882517      0.0    5000.0
# 2         2.173950    1.202943  0.553344  0.947042      0.0    9000.0
# 3         2.068879    1.123843  0.543213  0.952623      0.0   10000.0
# 4         2.150144    1.163233  0.541003  0.941646      0.0   10000.0
# ...            ...         ...       ...       ...      ...       ...
# 599995    0.184309    0.033168  0.179958  0.086705      0.4     700.0
# 599996    0.181849    0.010640  0.058508  0.054755      0.4     900.0
# 599997    0.265074    0.004225  0.015940  0.016758      0.4    3000.0
# 599998    0.193847    0.001301  0.006709  0.009228      0.4    4000.0
# 599999    0.819451    0.106342  0.129773  0.083984      0.4   12000.0
#
#           n_core    k_core   n_shell       k_shell  density   lambda  \
# 0       1.451990  0.022362  1.330928  4.128916e-08      2.6    700.0
# 1       1.453480  0.023396  1.327650  2.061950e-06      2.6    950.0
# 2       1.451020  0.018632  1.332398  9.574458e-09      2.6    600.0
# 3       1.483700  0.099080  1.389200  9.470000e-08      2.6    210.0
# 4       1.453000  0.022940  1.329120  3.110181e-07      2.6    850.0
# ...          ...       ...       ...           ...      ...      ...
# 599995  1.394680  0.006191  1.420600  1.426000e-01      1.7   4600.0
# 599996  1.364826  0.022669  1.276529  1.827067e-01      1.7   7100.0
# 599997  1.613500  0.648098  2.010000  6.500000e-01      1.7  50000.0
# 599998  1.613500  0.648098  2.020000  6.850000e-01      1.7  90000.0
# 599999  1.613500  0.648098  2.020000  6.850000e-01      1.7  90000.0
#
#                  x
# 0        17.951958
# 1        16.534698
# 2        47.123890
# 3       149.599650
# 4        36.959914
# ...            ...
# 599995    0.478068
# 599996    0.398230
# 599997    0.188496
# 599998    0.139626
# 599999    0.418879
#
# [600000 rows x 13 columns]
# time: 4.13 s (started: 2023-08-19 21:33:18 +02:00)

# %%
# df[["Extinction", "SSA", "Asym"]].to_csv('/work/bb1070/b382177/mie/icon/mie_out.txt', float_format='%.3f', sep=' ')
# df[['coating', 'x', 'n_core', 'k_core', 'n_shell', 'k_shell', 'lambda']].to_csv('/work/bb1070/b382177/mie/icon/mie_input.txt', float_format='%.3f', sep=' ')
# Out:
# time: 238 µs (started: 2023-08-19 21:33:22 +02:00)

# %%
mx = df.max()
mn = df.min()
pd.concat([pd.DataFrame(mx), pd.DataFrame(mn)], axis=1).to_csv('/work/bb1070/b382177/mie/icon/05-07-2023/model/mlp_min_max.csv')
# Out:
# time: 66.7 ms (started: 2023-08-19 21:33:22 +02:00)

# %%
qt = QuantileTransformer(n_quantiles=1000, output_distribution="normal", random_state=0)
df_shuffled = df.sample(frac=1, random_state=40).reset_index(drop=True)
df_shuffled = normalize1(df_shuffled)

out_col = ["Extinction", "Scattering", "Asym"]
in_col = ['coating', 'x', 'n_core', 'k_core', 'n_shell', 'k_shell', 'lambda']

y = df_shuffled[out_col]
y[out_col] = qt.fit_transform(y)
x = df_shuffled[in_col]

split = 0.9
train_size = int(split * len(x))
train_x = x.iloc[:train_size, :].reset_index(drop=True)
train_y = y.iloc[:train_size, :].reset_index(drop=True)
test_x = x.iloc[train_size:, :].reset_index(drop=True)
test_y = y.iloc[train_size:, :].reset_index(drop=True)
train_y
# Out:
#         Extinction  Scattering      Asym
# 0        -0.385656   -0.134130 -0.108732
# 1        -0.825163   -0.511151 -0.509331
# 2         1.483993    1.338700  0.826924
# 3        -0.051317   -0.452069 -0.513292
# 4         0.518457    0.429787  1.835915
# ...            ...         ...       ...
# 539995   -0.990207   -0.841703 -0.810697
# 539996    0.220158    0.192439  0.161772
# 539997   -0.956842   -5.199338 -1.599475
# 539998   -0.213032   -0.563891 -0.612526
# 539999   -0.487695   -0.670379 -0.625399
#
# [540000 rows x 3 columns]
# time: 615 ms (started: 2023-08-19 21:33:22 +02:00)

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)
model = create_model(
    7,
    3,
    # hidden=[15, 30, 60, 30, 15],
    hidden=[64, 64, 64, 64],
    # dropout=[0.05, 0.05, 0.05, 0.05],
    dropout=[0, 0, 0, 0, 0],
    # activation=["tanh", "tanh", "tanh", "tanh"],
    activation=["gelu", "gelu", "gelu", 'gelu', 'gelu'],
    # activation=["relu", "relu", "relu", 'relu', 'relu'],
    loss="mse",
    optimizer=opt,
    metrics=['mse', 'mae', 'mape']
)

mc = ModelCheckpoint('model/model_17-08-2023.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, save_weights_only=False)
es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=50)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)
tnan = TerminateOnNaN()
callbacks = [es, mc, tnan, rlr]

h = model.fit(
    train_x,
    train_y,
    epochs=5000,
    batch_size=128,
    verbose=0,
    validation_split=0.1,
    callbacks=callbacks,
    shuffle=True
)

pred_y = model.predict(test_x)
pred_y = pd.DataFrame(pred_y, columns=out_col)
# Out:
# Input shape: (7,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                512
#
#  dropout (Dropout)           (None, 64)                0
#
#  hidden_layer_2 (Dense)      (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  hidden_layer_3 (Dense)      (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  hidden_layer_4 (Dense)      (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  output_layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 13,187
# Trainable params: 13,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2023-08-19 21:33:23.294553: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-08-19 21:33:23.294589: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-08-19 21:33:23.294607: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (l40010.lvt.dkrz.de): /proc/driver/nvidia/version does not exist
# 2023-08-19 21:33:23.295652: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1: val_loss improved from inf to 0.69586, saving model to model/model_17-08-2023.h5
#
# Epoch 2: val_loss improved from 0.69586 to 0.56277, saving model to model/model_17-08-2023.h5
#
# Epoch 3: val_loss improved from 0.56277 to 0.38999, saving model to model/model_17-08-2023.h5
#
# Epoch 4: val_loss improved from 0.38999 to 0.18990, saving model to model/model_17-08-2023.h5
#
# Epoch 5: val_loss did not improve from 0.18990
#
# Epoch 6: val_loss did not improve from 0.18990
#
# Epoch 7: val_loss did not improve from 0.18990
#
# Epoch 8: val_loss did not improve from 0.18990
#
# Epoch 9: val_loss did not improve from 0.18990
#
# Epoch 10: val_loss improved from 0.18990 to 0.16412, saving model to model/model_17-08-2023.h5
#
# Epoch 11: val_loss did not improve from 0.16412
#
# Epoch 12: val_loss improved from 0.16412 to 0.12962, saving model to model/model_17-08-2023.h5
#
# Epoch 13: val_loss improved from 0.12962 to 0.10860, saving model to model/model_17-08-2023.h5
#
# Epoch 14: val_loss improved from 0.10860 to 0.09212, saving model to model/model_17-08-2023.h5
#
# Epoch 15: val_loss did not improve from 0.09212
#
# Epoch 16: val_loss improved from 0.09212 to 0.08000, saving model to model/model_17-08-2023.h5
#
# Epoch 17: val_loss did not improve from 0.08000
#
# Epoch 18: val_loss did not improve from 0.08000
#
# Epoch 19: val_loss did not improve from 0.08000
#
# Epoch 20: val_loss improved from 0.08000 to 0.06184, saving model to model/model_17-08-2023.h5
#
# Epoch 21: val_loss improved from 0.06184 to 0.05757, saving model to model/model_17-08-2023.h5
#
# Epoch 22: val_loss did not improve from 0.05757
#
# Epoch 23: val_loss did not improve from 0.05757
#
# Epoch 24: val_loss did not improve from 0.05757
#
# Epoch 25: val_loss did not improve from 0.05757
#
# Epoch 26: val_loss improved from 0.05757 to 0.05280, saving model to model/model_17-08-2023.h5
#
# Epoch 27: val_loss did not improve from 0.05280
#
# Epoch 28: val_loss did not improve from 0.05280
#
# Epoch 29: val_loss did not improve from 0.05280
#
# Epoch 30: val_loss did not improve from 0.05280
#
# Epoch 31: val_loss improved from 0.05280 to 0.05040, saving model to model/model_17-08-2023.h5
#
# Epoch 32: val_loss did not improve from 0.05040
#
# Epoch 33: val_loss did not improve from 0.05040
#
# Epoch 34: val_loss did not improve from 0.05040
#
# Epoch 35: val_loss did not improve from 0.05040
#
# Epoch 36: val_loss did not improve from 0.05040
#
# Epoch 37: val_loss did not improve from 0.05040
#
# Epoch 38: val_loss did not improve from 0.05040
#
# Epoch 39: val_loss improved from 0.05040 to 0.03617, saving model to model/model_17-08-2023.h5
#
# Epoch 40: val_loss did not improve from 0.03617
#
# Epoch 41: val_loss did not improve from 0.03617
#
# Epoch 42: val_loss improved from 0.03617 to 0.03548, saving model to model/model_17-08-2023.h5
#
# Epoch 43: val_loss improved from 0.03548 to 0.03219, saving model to model/model_17-08-2023.h5
#
# Epoch 44: val_loss did not improve from 0.03219
#
# Epoch 45: val_loss did not improve from 0.03219
#
# Epoch 46: val_loss did not improve from 0.03219
#
# Epoch 47: val_loss improved from 0.03219 to 0.03044, saving model to model/model_17-08-2023.h5
#
# Epoch 48: val_loss did not improve from 0.03044
#
# Epoch 49: val_loss did not improve from 0.03044
#
# Epoch 50: val_loss did not improve from 0.03044
#
# Epoch 51: val_loss did not improve from 0.03044
#
# Epoch 52: val_loss did not improve from 0.03044
#
# Epoch 53: val_loss improved from 0.03044 to 0.02929, saving model to model/model_17-08-2023.h5
#
# Epoch 54: val_loss improved from 0.02929 to 0.02909, saving model to model/model_17-08-2023.h5
#
# Epoch 55: val_loss did not improve from 0.02909
#
# Epoch 56: val_loss improved from 0.02909 to 0.02867, saving model to model/model_17-08-2023.h5
#
# Epoch 57: val_loss improved from 0.02867 to 0.02796, saving model to model/model_17-08-2023.h5
#
# Epoch 58: val_loss did not improve from 0.02796
#
# Epoch 59: val_loss improved from 0.02796 to 0.02783, saving model to model/model_17-08-2023.h5
#
# Epoch 60: val_loss improved from 0.02783 to 0.02732, saving model to model/model_17-08-2023.h5
#
# Epoch 61: val_loss improved from 0.02732 to 0.02731, saving model to model/model_17-08-2023.h5
#
# Epoch 62: val_loss improved from 0.02731 to 0.02634, saving model to model/model_17-08-2023.h5
#
# Epoch 63: val_loss did not improve from 0.02634
#
# Epoch 64: val_loss did not improve from 0.02634
#
# Epoch 65: val_loss did not improve from 0.02634
#
# Epoch 66: val_loss improved from 0.02634 to 0.02604, saving model to model/model_17-08-2023.h5
#
# Epoch 67: val_loss did not improve from 0.02604
#
# Epoch 68: val_loss did not improve from 0.02604
#
# Epoch 69: val_loss did not improve from 0.02604
#
# Epoch 70: val_loss did not improve from 0.02604
#
# Epoch 71: val_loss improved from 0.02604 to 0.02478, saving model to model/model_17-08-2023.h5
#
# Epoch 72: val_loss did not improve from 0.02478
#
# Epoch 73: val_loss did not improve from 0.02478
#
# Epoch 74: val_loss did not improve from 0.02478
#
# Epoch 75: val_loss did not improve from 0.02478
#
# Epoch 76: val_loss did not improve from 0.02478
#
# Epoch 77: val_loss improved from 0.02478 to 0.02432, saving model to model/model_17-08-2023.h5
#
# Epoch 78: val_loss improved from 0.02432 to 0.02430, saving model to model/model_17-08-2023.h5
#
# Epoch 79: val_loss did not improve from 0.02430
#
# Epoch 80: val_loss did not improve from 0.02430
#
# Epoch 81: val_loss did not improve from 0.02430
#
# Epoch 82: val_loss did not improve from 0.02430
#
# Epoch 83: val_loss improved from 0.02430 to 0.02388, saving model to model/model_17-08-2023.h5
#
# Epoch 84: val_loss did not improve from 0.02388
#
# Epoch 85: val_loss did not improve from 0.02388
#
# Epoch 86: val_loss improved from 0.02388 to 0.02379, saving model to model/model_17-08-2023.h5
#
# Epoch 87: val_loss did not improve from 0.02379
#
# Epoch 88: val_loss improved from 0.02379 to 0.02378, saving model to model/model_17-08-2023.h5
#
# Epoch 89: val_loss did not improve from 0.02378
#
# Epoch 90: val_loss did not improve from 0.02378
#
# Epoch 91: val_loss did not improve from 0.02378
#
# Epoch 92: val_loss improved from 0.02378 to 0.02373, saving model to model/model_17-08-2023.h5
#
# Epoch 93: val_loss did not improve from 0.02373
#
# Epoch 94: val_loss did not improve from 0.02373
#
# Epoch 95: val_loss did not improve from 0.02373
#
# Epoch 96: val_loss did not improve from 0.02373
#
# Epoch 97: val_loss improved from 0.02373 to 0.02357, saving model to model/model_17-08-2023.h5
#
# Epoch 98: val_loss improved from 0.02357 to 0.02354, saving model to model/model_17-08-2023.h5
#
# Epoch 99: val_loss did not improve from 0.02354
#
# Epoch 100: val_loss did not improve from 0.02354
#
# Epoch 101: val_loss did not improve from 0.02354
#
# Epoch 102: val_loss did not improve from 0.02354
#
# Epoch 103: val_loss improved from 0.02354 to 0.02350, saving model to model/model_17-08-2023.h5
#
# Epoch 104: val_loss improved from 0.02350 to 0.02343, saving model to model/model_17-08-2023.h5
#
# Epoch 105: val_loss did not improve from 0.02343
#
# Epoch 106: val_loss did not improve from 0.02343
#
# Epoch 107: val_loss did not improve from 0.02343
#
# Epoch 108: val_loss did not improve from 0.02343
#
# Epoch 109: val_loss improved from 0.02343 to 0.02338, saving model to model/model_17-08-2023.h5
#
# Epoch 110: val_loss did not improve from 0.02338
#
# Epoch 111: val_loss improved from 0.02338 to 0.02335, saving model to model/model_17-08-2023.h5
#
# Epoch 112: val_loss did not improve from 0.02335
#
# Epoch 113: val_loss did not improve from 0.02335
#
# Epoch 114: val_loss improved from 0.02335 to 0.02330, saving model to model/model_17-08-2023.h5
#
# Epoch 115: val_loss did not improve from 0.02330
#
# Epoch 116: val_loss did not improve from 0.02330
#
# Epoch 117: val_loss improved from 0.02330 to 0.02325, saving model to model/model_17-08-2023.h5
#
# Epoch 118: val_loss did not improve from 0.02325
#
# Epoch 119: val_loss did not improve from 0.02325
#
# Epoch 120: val_loss improved from 0.02325 to 0.02317, saving model to model/model_17-08-2023.h5
#
# Epoch 121: val_loss did not improve from 0.02317
#
# Epoch 122: val_loss did not improve from 0.02317
#
# Epoch 123: val_loss improved from 0.02317 to 0.02313, saving model to model/model_17-08-2023.h5
#
# Epoch 124: val_loss did not improve from 0.02313
#
# Epoch 125: val_loss did not improve from 0.02313
#
# Epoch 126: val_loss did not improve from 0.02313
#
# Epoch 127: val_loss improved from 0.02313 to 0.02307, saving model to model/model_17-08-2023.h5
#
# Epoch 128: val_loss did not improve from 0.02307
#
# Epoch 129: val_loss improved from 0.02307 to 0.02297, saving model to model/model_17-08-2023.h5
#
# Epoch 130: val_loss did not improve from 0.02297
#
# Epoch 131: val_loss did not improve from 0.02297
#
# Epoch 132: val_loss improved from 0.02297 to 0.02295, saving model to model/model_17-08-2023.h5
#
# Epoch 133: val_loss did not improve from 0.02295
#
# Epoch 134: val_loss did not improve from 0.02295
#
# Epoch 135: val_loss did not improve from 0.02295
#
# Epoch 136: val_loss improved from 0.02295 to 0.02287, saving model to model/model_17-08-2023.h5
#
# Epoch 137: val_loss did not improve from 0.02287
#
# Epoch 138: val_loss improved from 0.02287 to 0.02283, saving model to model/model_17-08-2023.h5
#
# Epoch 139: val_loss did not improve from 0.02283
#
# Epoch 140: val_loss did not improve from 0.02283
#
# Epoch 141: val_loss did not improve from 0.02283
#
# Epoch 142: val_loss did not improve from 0.02283
#
# Epoch 143: val_loss did not improve from 0.02283
#
# Epoch 144: val_loss improved from 0.02283 to 0.02277, saving model to model/model_17-08-2023.h5
#
# Epoch 145: val_loss did not improve from 0.02277
#
# Epoch 146: val_loss did not improve from 0.02277
#
# Epoch 147: val_loss improved from 0.02277 to 0.02265, saving model to model/model_17-08-2023.h5
#
# Epoch 148: val_loss did not improve from 0.02265
#
# Epoch 149: val_loss did not improve from 0.02265
#
# Epoch 150: val_loss did not improve from 0.02265
#
# Epoch 151: val_loss did not improve from 0.02265
#
# Epoch 152: val_loss did not improve from 0.02265
#
# Epoch 153: val_loss did not improve from 0.02265
#
# Epoch 154: val_loss did not improve from 0.02265
#
# Epoch 155: val_loss did not improve from 0.02265
#
# Epoch 156: val_loss did not improve from 0.02265
#
# Epoch 157: val_loss did not improve from 0.02265
#
# Epoch 158: val_loss improved from 0.02265 to 0.02257, saving model to model/model_17-08-2023.h5
#
# Epoch 159: val_loss improved from 0.02257 to 0.02253, saving model to model/model_17-08-2023.h5
#
# Epoch 160: val_loss did not improve from 0.02253
#
# Epoch 161: val_loss did not improve from 0.02253
#
# Epoch 162: val_loss did not improve from 0.02253
#
# Epoch 163: val_loss did not improve from 0.02253
#
# Epoch 164: val_loss improved from 0.02253 to 0.02245, saving model to model/model_17-08-2023.h5
#
# Epoch 165: val_loss improved from 0.02245 to 0.02238, saving model to model/model_17-08-2023.h5
#
# Epoch 166: val_loss did not improve from 0.02238
#
# Epoch 167: val_loss did not improve from 0.02238
#
# Epoch 168: val_loss did not improve from 0.02238
#
# Epoch 169: val_loss improved from 0.02238 to 0.02234, saving model to model/model_17-08-2023.h5
#
# Epoch 170: val_loss improved from 0.02234 to 0.02229, saving model to model/model_17-08-2023.h5
#
# Epoch 171: val_loss did not improve from 0.02229
#
# Epoch 172: val_loss improved from 0.02229 to 0.02226, saving model to model/model_17-08-2023.h5
#
# Epoch 173: val_loss did not improve from 0.02226
#
# Epoch 174: val_loss did not improve from 0.02226
#
# Epoch 175: val_loss did not improve from 0.02226
#
# Epoch 176: val_loss did not improve from 0.02226
#
# Epoch 177: val_loss did not improve from 0.02226
#
# Epoch 178: val_loss did not improve from 0.02226
#
# Epoch 179: val_loss improved from 0.02226 to 0.02226, saving model to model/model_17-08-2023.h5
#
# Epoch 180: val_loss did not improve from 0.02226
#
# Epoch 181: val_loss did not improve from 0.02226
#
# Epoch 182: val_loss improved from 0.02226 to 0.02218, saving model to model/model_17-08-2023.h5
#
# Epoch 183: val_loss did not improve from 0.02218
#
# Epoch 184: val_loss improved from 0.02218 to 0.02214, saving model to model/model_17-08-2023.h5
#
# Epoch 185: val_loss improved from 0.02214 to 0.02212, saving model to model/model_17-08-2023.h5
#
# Epoch 186: val_loss improved from 0.02212 to 0.02210, saving model to model/model_17-08-2023.h5
#
# Epoch 187: val_loss did not improve from 0.02210
#
# Epoch 188: val_loss improved from 0.02210 to 0.02205, saving model to model/model_17-08-2023.h5
#
# Epoch 189: val_loss did not improve from 0.02205
#
# Epoch 190: val_loss did not improve from 0.02205
#
# Epoch 191: val_loss did not improve from 0.02205
#
# Epoch 192: val_loss improved from 0.02205 to 0.02199, saving model to model/model_17-08-2023.h5
#
# Epoch 193: val_loss did not improve from 0.02199
#
# Epoch 194: val_loss improved from 0.02199 to 0.02194, saving model to model/model_17-08-2023.h5
#
# Epoch 195: val_loss did not improve from 0.02194
#
# Epoch 196: val_loss did not improve from 0.02194
#
# Epoch 197: val_loss improved from 0.02194 to 0.02190, saving model to model/model_17-08-2023.h5
#
# Epoch 198: val_loss did not improve from 0.02190
#
# Epoch 199: val_loss did not improve from 0.02190
#
# Epoch 200: val_loss did not improve from 0.02190
#
# Epoch 201: val_loss did not improve from 0.02190
#
# Epoch 202: val_loss improved from 0.02190 to 0.02182, saving model to model/model_17-08-2023.h5
#
# Epoch 203: val_loss did not improve from 0.02182
#
# Epoch 204: val_loss did not improve from 0.02182
#
# Epoch 205: val_loss did not improve from 0.02182
#
# Epoch 206: val_loss did not improve from 0.02182
#
# Epoch 207: val_loss did not improve from 0.02182
#
# Epoch 208: val_loss improved from 0.02182 to 0.02173, saving model to model/model_17-08-2023.h5
#
# Epoch 209: val_loss did not improve from 0.02173
#
# Epoch 210: val_loss did not improve from 0.02173
#
# Epoch 211: val_loss did not improve from 0.02173
#
# Epoch 212: val_loss did not improve from 0.02173
#
# Epoch 213: val_loss did not improve from 0.02173
#
# Epoch 214: val_loss did not improve from 0.02173
#
# Epoch 215: val_loss did not improve from 0.02173
#
# Epoch 216: val_loss did not improve from 0.02173
#
# Epoch 217: val_loss did not improve from 0.02173
#
# Epoch 218: val_loss improved from 0.02173 to 0.02171, saving model to model/model_17-08-2023.h5
#
# Epoch 219: val_loss improved from 0.02171 to 0.02156, saving model to model/model_17-08-2023.h5
#
# Epoch 220: val_loss did not improve from 0.02156
#
# Epoch 221: val_loss did not improve from 0.02156
#
# Epoch 222: val_loss did not improve from 0.02156
#
# Epoch 223: val_loss did not improve from 0.02156
#
# Epoch 224: val_loss did not improve from 0.02156
#
# Epoch 225: val_loss did not improve from 0.02156
#
# Epoch 226: val_loss did not improve from 0.02156
#
# Epoch 227: val_loss did not improve from 0.02156
#
# Epoch 228: val_loss improved from 0.02156 to 0.02153, saving model to model/model_17-08-2023.h5
#
# Epoch 229: val_loss did not improve from 0.02153
#
# Epoch 230: val_loss improved from 0.02153 to 0.02149, saving model to model/model_17-08-2023.h5
#
# Epoch 231: val_loss did not improve from 0.02149
#
# Epoch 232: val_loss did not improve from 0.02149
#
# Epoch 233: val_loss did not improve from 0.02149
#
# Epoch 234: val_loss did not improve from 0.02149
#
# Epoch 235: val_loss improved from 0.02149 to 0.02132, saving model to model/model_17-08-2023.h5
#
# Epoch 236: val_loss improved from 0.02132 to 0.02129, saving model to model/model_17-08-2023.h5
#
# Epoch 237: val_loss did not improve from 0.02129
#
# Epoch 238: val_loss did not improve from 0.02129
#
# Epoch 239: val_loss did not improve from 0.02129
#
# Epoch 240: val_loss did not improve from 0.02129
#
# Epoch 241: val_loss did not improve from 0.02129
#
# Epoch 242: val_loss improved from 0.02129 to 0.02126, saving model to model/model_17-08-2023.h5
#
# Epoch 243: val_loss improved from 0.02126 to 0.02124, saving model to model/model_17-08-2023.h5
#
# Epoch 244: val_loss did not improve from 0.02124
#
# Epoch 245: val_loss did not improve from 0.02124
#
# Epoch 246: val_loss did not improve from 0.02124
#
# Epoch 247: val_loss did not improve from 0.02124
#
# Epoch 248: val_loss did not improve from 0.02124
#
# Epoch 249: val_loss did not improve from 0.02124
#
# Epoch 250: val_loss did not improve from 0.02124
#
# Epoch 251: val_loss improved from 0.02124 to 0.02121, saving model to model/model_17-08-2023.h5
#
# Epoch 252: val_loss improved from 0.02121 to 0.02109, saving model to model/model_17-08-2023.h5
#
# Epoch 253: val_loss did not improve from 0.02109
#
# Epoch 254: val_loss did not improve from 0.02109
#
# Epoch 255: val_loss did not improve from 0.02109
#
# Epoch 256: val_loss improved from 0.02109 to 0.02104, saving model to model/model_17-08-2023.h5
#
# Epoch 257: val_loss did not improve from 0.02104
#
# Epoch 258: val_loss did not improve from 0.02104
#
# Epoch 259: val_loss did not improve from 0.02104
#
# Epoch 260: val_loss did not improve from 0.02104
#
# Epoch 261: val_loss improved from 0.02104 to 0.02102, saving model to model/model_17-08-2023.h5
#
# Epoch 262: val_loss did not improve from 0.02102
#
# Epoch 263: val_loss improved from 0.02102 to 0.02094, saving model to model/model_17-08-2023.h5
#
# Epoch 264: val_loss did not improve from 0.02094
#
# Epoch 265: val_loss did not improve from 0.02094
#
# Epoch 266: val_loss did not improve from 0.02094
#
# Epoch 267: val_loss did not improve from 0.02094
#
# Epoch 268: val_loss did not improve from 0.02094
#
# Epoch 269: val_loss improved from 0.02094 to 0.02084, saving model to model/model_17-08-2023.h5
#
# Epoch 270: val_loss did not improve from 0.02084
#
# Epoch 271: val_loss did not improve from 0.02084
#
# Epoch 272: val_loss did not improve from 0.02084
#
# Epoch 273: val_loss improved from 0.02084 to 0.02080, saving model to model/model_17-08-2023.h5
#
# Epoch 274: val_loss did not improve from 0.02080
#
# Epoch 275: val_loss did not improve from 0.02080
#
# Epoch 276: val_loss did not improve from 0.02080
#
# Epoch 277: val_loss did not improve from 0.02080
#
# Epoch 278: val_loss improved from 0.02080 to 0.02071, saving model to model/model_17-08-2023.h5
#
# Epoch 279: val_loss did not improve from 0.02071
#
# Epoch 280: val_loss did not improve from 0.02071
#
# Epoch 281: val_loss did not improve from 0.02071
#
# Epoch 282: val_loss did not improve from 0.02071
#
# Epoch 283: val_loss did not improve from 0.02071
#
# Epoch 284: val_loss did not improve from 0.02071
#
# Epoch 285: val_loss improved from 0.02071 to 0.02068, saving model to model/model_17-08-2023.h5
#
# Epoch 286: val_loss improved from 0.02068 to 0.02062, saving model to model/model_17-08-2023.h5
#
# Epoch 287: val_loss did not improve from 0.02062
#
# Epoch 288: val_loss did not improve from 0.02062
#
# Epoch 289: val_loss did not improve from 0.02062
#
# Epoch 290: val_loss improved from 0.02062 to 0.02056, saving model to model/model_17-08-2023.h5
#
# Epoch 291: val_loss did not improve from 0.02056
#
# Epoch 292: val_loss did not improve from 0.02056
#
# Epoch 293: val_loss did not improve from 0.02056
#
# Epoch 294: val_loss did not improve from 0.02056
#
# Epoch 295: val_loss did not improve from 0.02056
#
# Epoch 296: val_loss did not improve from 0.02056
#
# Epoch 297: val_loss improved from 0.02056 to 0.02053, saving model to model/model_17-08-2023.h5
#
# Epoch 298: val_loss improved from 0.02053 to 0.02047, saving model to model/model_17-08-2023.h5
#
# Epoch 299: val_loss improved from 0.02047 to 0.02042, saving model to model/model_17-08-2023.h5
#
# Epoch 300: val_loss did not improve from 0.02042
#
# Epoch 301: val_loss did not improve from 0.02042
#
# Epoch 302: val_loss did not improve from 0.02042
#
# Epoch 303: val_loss improved from 0.02042 to 0.02036, saving model to model/model_17-08-2023.h5
#
# Epoch 304: val_loss did not improve from 0.02036
#
# Epoch 305: val_loss did not improve from 0.02036
#
# Epoch 306: val_loss did not improve from 0.02036
#
# Epoch 307: val_loss did not improve from 0.02036
#
# Epoch 308: val_loss did not improve from 0.02036
#
# Epoch 309: val_loss did not improve from 0.02036
#
# Epoch 310: val_loss improved from 0.02036 to 0.02033, saving model to model/model_17-08-2023.h5
#
# Epoch 311: val_loss improved from 0.02033 to 0.02030, saving model to model/model_17-08-2023.h5
#
# Epoch 312: val_loss did not improve from 0.02030
#
# Epoch 313: val_loss improved from 0.02030 to 0.02024, saving model to model/model_17-08-2023.h5
#
# Epoch 314: val_loss did not improve from 0.02024
#
# Epoch 315: val_loss did not improve from 0.02024
#
# Epoch 316: val_loss did not improve from 0.02024
#
# Epoch 317: val_loss did not improve from 0.02024
#
# Epoch 318: val_loss improved from 0.02024 to 0.02019, saving model to model/model_17-08-2023.h5
#
# Epoch 319: val_loss improved from 0.02019 to 0.02013, saving model to model/model_17-08-2023.h5
#
# Epoch 320: val_loss did not improve from 0.02013
#
# Epoch 321: val_loss did not improve from 0.02013
#
# Epoch 322: val_loss did not improve from 0.02013
#
# Epoch 323: val_loss did not improve from 0.02013
#
# Epoch 324: val_loss improved from 0.02013 to 0.02010, saving model to model/model_17-08-2023.h5
#
# Epoch 325: val_loss did not improve from 0.02010
#
# Epoch 326: val_loss improved from 0.02010 to 0.02008, saving model to model/model_17-08-2023.h5
#
# Epoch 327: val_loss improved from 0.02008 to 0.02003, saving model to model/model_17-08-2023.h5
#
# Epoch 328: val_loss did not improve from 0.02003
#
# Epoch 329: val_loss did not improve from 0.02003
#
# Epoch 330: val_loss improved from 0.02003 to 0.02003, saving model to model/model_17-08-2023.h5
#
# Epoch 331: val_loss did not improve from 0.02003
#
# Epoch 332: val_loss did not improve from 0.02003
#
# Epoch 333: val_loss did not improve from 0.02003
#
# Epoch 334: val_loss improved from 0.02003 to 0.02003, saving model to model/model_17-08-2023.h5
#
# Epoch 335: val_loss did not improve from 0.02003
#
# Epoch 336: val_loss improved from 0.02003 to 0.01994, saving model to model/model_17-08-2023.h5
#
# Epoch 337: val_loss improved from 0.01994 to 0.01989, saving model to model/model_17-08-2023.h5
#
# Epoch 338: val_loss did not improve from 0.01989
#
# Epoch 339: val_loss did not improve from 0.01989
#
# Epoch 340: val_loss did not improve from 0.01989
#
# Epoch 341: val_loss did not improve from 0.01989
#
# Epoch 342: val_loss did not improve from 0.01989
#
# Epoch 343: val_loss did not improve from 0.01989
#
# Epoch 344: val_loss did not improve from 0.01989
#
# Epoch 345: val_loss did not improve from 0.01989
#
# Epoch 346: val_loss did not improve from 0.01989
#
# Epoch 347: val_loss improved from 0.01989 to 0.01987, saving model to model/model_17-08-2023.h5
#
# Epoch 348: val_loss did not improve from 0.01987
#
# Epoch 349: val_loss improved from 0.01987 to 0.01987, saving model to model/model_17-08-2023.h5
#
# Epoch 350: val_loss improved from 0.01987 to 0.01982, saving model to model/model_17-08-2023.h5
#
# Epoch 351: val_loss improved from 0.01982 to 0.01980, saving model to model/model_17-08-2023.h5
#
# Epoch 352: val_loss improved from 0.01980 to 0.01973, saving model to model/model_17-08-2023.h5
#
# Epoch 353: val_loss did not improve from 0.01973
#
# Epoch 354: val_loss did not improve from 0.01973
#
# Epoch 355: val_loss did not improve from 0.01973
#
# Epoch 356: val_loss did not improve from 0.01973
#
# Epoch 357: val_loss did not improve from 0.01973
#
# Epoch 358: val_loss improved from 0.01973 to 0.01972, saving model to model/model_17-08-2023.h5
#
# Epoch 359: val_loss did not improve from 0.01972
#
# Epoch 360: val_loss did not improve from 0.01972
#
# Epoch 361: val_loss improved from 0.01972 to 0.01968, saving model to model/model_17-08-2023.h5
#
# Epoch 362: val_loss did not improve from 0.01968
#
# Epoch 363: val_loss improved from 0.01968 to 0.01965, saving model to model/model_17-08-2023.h5
#
# Epoch 364: val_loss did not improve from 0.01965
#
# Epoch 365: val_loss did not improve from 0.01965
#
# Epoch 366: val_loss improved from 0.01965 to 0.01961, saving model to model/model_17-08-2023.h5
#
# Epoch 367: val_loss did not improve from 0.01961
#
# Epoch 368: val_loss improved from 0.01961 to 0.01954, saving model to model/model_17-08-2023.h5
#
# Epoch 369: val_loss did not improve from 0.01954
#
# Epoch 370: val_loss did not improve from 0.01954
#
# Epoch 371: val_loss did not improve from 0.01954
#
# Epoch 372: val_loss did not improve from 0.01954
#
# Epoch 373: val_loss improved from 0.01954 to 0.01952, saving model to model/model_17-08-2023.h5
#
# Epoch 374: val_loss did not improve from 0.01952
#
# Epoch 375: val_loss did not improve from 0.01952
#
# Epoch 376: val_loss did not improve from 0.01952
#
# Epoch 377: val_loss improved from 0.01952 to 0.01945, saving model to model/model_17-08-2023.h5
#
# Epoch 378: val_loss did not improve from 0.01945
#
# Epoch 379: val_loss did not improve from 0.01945
#
# Epoch 380: val_loss improved from 0.01945 to 0.01943, saving model to model/model_17-08-2023.h5
#
# Epoch 381: val_loss did not improve from 0.01943
#
# Epoch 382: val_loss did not improve from 0.01943
#
# Epoch 383: val_loss did not improve from 0.01943
#
# Epoch 384: val_loss did not improve from 0.01943
#
# Epoch 385: val_loss improved from 0.01943 to 0.01942, saving model to model/model_17-08-2023.h5
#
# Epoch 386: val_loss did not improve from 0.01942
#
# Epoch 387: val_loss improved from 0.01942 to 0.01938, saving model to model/model_17-08-2023.h5
#
# Epoch 388: val_loss did not improve from 0.01938
#
# Epoch 389: val_loss did not improve from 0.01938
#
# Epoch 390: val_loss did not improve from 0.01938
#
# Epoch 391: val_loss did not improve from 0.01938
#
# Epoch 392: val_loss did not improve from 0.01938
#
# Epoch 393: val_loss did not improve from 0.01938
#
# Epoch 394: val_loss did not improve from 0.01938
#
# Epoch 395: val_loss improved from 0.01938 to 0.01936, saving model to model/model_17-08-2023.h5
#
# Epoch 396: val_loss did not improve from 0.01936
#
# Epoch 397: val_loss did not improve from 0.01936
#
# Epoch 398: val_loss did not improve from 0.01936
#
# Epoch 399: val_loss did not improve from 0.01936
#
# Epoch 400: val_loss improved from 0.01936 to 0.01927, saving model to model/model_17-08-2023.h5
#
# Epoch 401: val_loss improved from 0.01927 to 0.01923, saving model to model/model_17-08-2023.h5
#
# Epoch 402: val_loss did not improve from 0.01923
#
# Epoch 403: val_loss improved from 0.01923 to 0.01921, saving model to model/model_17-08-2023.h5
#
# Epoch 404: val_loss did not improve from 0.01921
#
# Epoch 405: val_loss did not improve from 0.01921
#
# Epoch 406: val_loss did not improve from 0.01921
#
# Epoch 407: val_loss improved from 0.01921 to 0.01908, saving model to model/model_17-08-2023.h5
#
# Epoch 408: val_loss did not improve from 0.01908
#
# Epoch 409: val_loss did not improve from 0.01908
#
# Epoch 410: val_loss did not improve from 0.01908
#
# Epoch 411: val_loss did not improve from 0.01908
#
# Epoch 412: val_loss did not improve from 0.01908
#
# Epoch 413: val_loss did not improve from 0.01908
#
# Epoch 414: val_loss did not improve from 0.01908
#
# Epoch 415: val_loss did not improve from 0.01908
#
# Epoch 416: val_loss did not improve from 0.01908
#
# Epoch 417: val_loss did not improve from 0.01908
#
# Epoch 418: val_loss did not improve from 0.01908
#
# Epoch 419: val_loss improved from 0.01908 to 0.01901, saving model to model/model_17-08-2023.h5
#
# Epoch 420: val_loss did not improve from 0.01901
#
# Epoch 421: val_loss did not improve from 0.01901
#
# Epoch 422: val_loss did not improve from 0.01901
#
# Epoch 423: val_loss did not improve from 0.01901
#
# Epoch 424: val_loss improved from 0.01901 to 0.01891, saving model to model/model_17-08-2023.h5
#
# Epoch 425: val_loss did not improve from 0.01891
#
# Epoch 426: val_loss did not improve from 0.01891
#
# Epoch 427: val_loss did not improve from 0.01891
#
# Epoch 428: val_loss did not improve from 0.01891
#
# Epoch 429: val_loss did not improve from 0.01891
#
# Epoch 430: val_loss did not improve from 0.01891
#
# Epoch 431: val_loss did not improve from 0.01891
#
# Epoch 432: val_loss improved from 0.01891 to 0.01883, saving model to model/model_17-08-2023.h5
#
# Epoch 433: val_loss did not improve from 0.01883
#
# Epoch 434: val_loss improved from 0.01883 to 0.01882, saving model to model/model_17-08-2023.h5
#
# Epoch 435: val_loss improved from 0.01882 to 0.01881, saving model to model/model_17-08-2023.h5
#
# Epoch 436: val_loss did not improve from 0.01881
#
# Epoch 437: val_loss did not improve from 0.01881
#
# Epoch 438: val_loss did not improve from 0.01881
#
# Epoch 439: val_loss did not improve from 0.01881
#
# Epoch 440: val_loss improved from 0.01881 to 0.01881, saving model to model/model_17-08-2023.h5
#
# Epoch 441: val_loss did not improve from 0.01881
#
# Epoch 442: val_loss did not improve from 0.01881
#
# Epoch 443: val_loss did not improve from 0.01881
#
# Epoch 444: val_loss did not improve from 0.01881
#
# Epoch 445: val_loss improved from 0.01881 to 0.01873, saving model to model/model_17-08-2023.h5
#
# Epoch 446: val_loss did not improve from 0.01873
#
# Epoch 447: val_loss did not improve from 0.01873
#
# Epoch 448: val_loss did not improve from 0.01873
#
# Epoch 449: val_loss did not improve from 0.01873
#
# Epoch 450: val_loss did not improve from 0.01873
#
# Epoch 451: val_loss improved from 0.01873 to 0.01868, saving model to model/model_17-08-2023.h5
#
# Epoch 452: val_loss did not improve from 0.01868
#
# Epoch 453: val_loss did not improve from 0.01868
#
# Epoch 454: val_loss did not improve from 0.01868
#
# Epoch 455: val_loss did not improve from 0.01868
#
# Epoch 456: val_loss did not improve from 0.01868
#
# Epoch 457: val_loss improved from 0.01868 to 0.01865, saving model to model/model_17-08-2023.h5
#
# Epoch 458: val_loss did not improve from 0.01865
#
# Epoch 459: val_loss did not improve from 0.01865
#
# Epoch 460: val_loss did not improve from 0.01865
#
# Epoch 461: val_loss did not improve from 0.01865
#
# Epoch 462: val_loss did not improve from 0.01865
#
# Epoch 463: val_loss improved from 0.01865 to 0.01856, saving model to model/model_17-08-2023.h5
#
# Epoch 464: val_loss did not improve from 0.01856
#
# Epoch 465: val_loss did not improve from 0.01856
#
# Epoch 466: val_loss did not improve from 0.01856
#
# Epoch 467: val_loss improved from 0.01856 to 0.01854, saving model to model/model_17-08-2023.h5
#
# Epoch 468: val_loss did not improve from 0.01854
#
# Epoch 469: val_loss did not improve from 0.01854
#
# Epoch 470: val_loss improved from 0.01854 to 0.01851, saving model to model/model_17-08-2023.h5
#
# Epoch 471: val_loss improved from 0.01851 to 0.01851, saving model to model/model_17-08-2023.h5
#
# Epoch 472: val_loss did not improve from 0.01851
#
# Epoch 473: val_loss improved from 0.01851 to 0.01844, saving model to model/model_17-08-2023.h5
#
# Epoch 474: val_loss improved from 0.01844 to 0.01844, saving model to model/model_17-08-2023.h5
#
# Epoch 475: val_loss improved from 0.01844 to 0.01843, saving model to model/model_17-08-2023.h5
#
# Epoch 476: val_loss did not improve from 0.01843
#
# Epoch 477: val_loss did not improve from 0.01843
#
# Epoch 478: val_loss did not improve from 0.01843
#
# Epoch 479: val_loss did not improve from 0.01843
#
# Epoch 480: val_loss did not improve from 0.01843
#
# Epoch 481: val_loss did not improve from 0.01843
#
# Epoch 482: val_loss improved from 0.01843 to 0.01840, saving model to model/model_17-08-2023.h5
#
# Epoch 483: val_loss did not improve from 0.01840
#
# Epoch 484: val_loss did not improve from 0.01840
#
# Epoch 485: val_loss improved from 0.01840 to 0.01836, saving model to model/model_17-08-2023.h5
#
# Epoch 486: val_loss improved from 0.01836 to 0.01830, saving model to model/model_17-08-2023.h5
#
# Epoch 487: val_loss did not improve from 0.01830
#
# Epoch 488: val_loss did not improve from 0.01830
#
# Epoch 489: val_loss did not improve from 0.01830
#
# Epoch 490: val_loss did not improve from 0.01830
#
# Epoch 491: val_loss did not improve from 0.01830
#
# Epoch 492: val_loss did not improve from 0.01830
#
# Epoch 493: val_loss did not improve from 0.01830
#
# Epoch 494: val_loss improved from 0.01830 to 0.01827, saving model to model/model_17-08-2023.h5
#
# Epoch 495: val_loss did not improve from 0.01827
#
# Epoch 496: val_loss did not improve from 0.01827
#
# Epoch 497: val_loss did not improve from 0.01827
#
# Epoch 498: val_loss did not improve from 0.01827
#
# Epoch 499: val_loss did not improve from 0.01827
#
# Epoch 500: val_loss did not improve from 0.01827
#
# Epoch 501: val_loss did not improve from 0.01827
#
# Epoch 502: val_loss improved from 0.01827 to 0.01816, saving model to model/model_17-08-2023.h5
#
# Epoch 503: val_loss improved from 0.01816 to 0.01814, saving model to model/model_17-08-2023.h5
#
# Epoch 504: val_loss did not improve from 0.01814
#
# Epoch 505: val_loss did not improve from 0.01814
#
# Epoch 506: val_loss did not improve from 0.01814
#
# Epoch 507: val_loss did not improve from 0.01814
#
# Epoch 508: val_loss did not improve from 0.01814
#
# Epoch 509: val_loss did not improve from 0.01814
#
# Epoch 510: val_loss did not improve from 0.01814
#
# Epoch 511: val_loss did not improve from 0.01814
#
# Epoch 512: val_loss improved from 0.01814 to 0.01812, saving model to model/model_17-08-2023.h5
#
# Epoch 513: val_loss did not improve from 0.01812
#
# Epoch 514: val_loss improved from 0.01812 to 0.01810, saving model to model/model_17-08-2023.h5
#
# Epoch 515: val_loss did not improve from 0.01810
#
# Epoch 516: val_loss improved from 0.01810 to 0.01806, saving model to model/model_17-08-2023.h5
#
# Epoch 517: val_loss did not improve from 0.01806
#
# Epoch 518: val_loss improved from 0.01806 to 0.01802, saving model to model/model_17-08-2023.h5
#
# Epoch 519: val_loss did not improve from 0.01802
#
# Epoch 520: val_loss did not improve from 0.01802
#
# Epoch 521: val_loss did not improve from 0.01802
#
# Epoch 522: val_loss did not improve from 0.01802
#
# Epoch 523: val_loss did not improve from 0.01802
#
# Epoch 524: val_loss did not improve from 0.01802
#
# Epoch 525: val_loss did not improve from 0.01802
#
# Epoch 526: val_loss did not improve from 0.01802
#
# Epoch 527: val_loss did not improve from 0.01802
#
# Epoch 528: val_loss did not improve from 0.01802
#
# Epoch 529: val_loss did not improve from 0.01802
#
# Epoch 530: val_loss did not improve from 0.01802
#
# Epoch 531: val_loss did not improve from 0.01802
#
# Epoch 532: val_loss did not improve from 0.01802
#
# Epoch 533: val_loss did not improve from 0.01802
#
# Epoch 534: val_loss did not improve from 0.01802
#
# Epoch 535: val_loss did not improve from 0.01802
#
# Epoch 536: val_loss did not improve from 0.01802
#
# Epoch 537: val_loss did not improve from 0.01802
#
# Epoch 538: val_loss did not improve from 0.01802
#
# Epoch 539: val_loss improved from 0.01802 to 0.01795, saving model to model/model_17-08-2023.h5
#
# Epoch 540: val_loss improved from 0.01795 to 0.01794, saving model to model/model_17-08-2023.h5
#
# Epoch 541: val_loss did not improve from 0.01794
#
# Epoch 542: val_loss did not improve from 0.01794
#
# Epoch 543: val_loss did not improve from 0.01794
#
# Epoch 544: val_loss did not improve from 0.01794
#
# Epoch 545: val_loss improved from 0.01794 to 0.01784, saving model to model/model_17-08-2023.h5
#
# Epoch 546: val_loss did not improve from 0.01784
#
# Epoch 547: val_loss improved from 0.01784 to 0.01776, saving model to model/model_17-08-2023.h5
#
# Epoch 548: val_loss did not improve from 0.01776
#
# Epoch 549: val_loss did not improve from 0.01776
#
# Epoch 550: val_loss did not improve from 0.01776
#
# Epoch 551: val_loss did not improve from 0.01776
#
# Epoch 552: val_loss did not improve from 0.01776
#
# Epoch 553: val_loss did not improve from 0.01776
#
# Epoch 554: val_loss did not improve from 0.01776
#
# Epoch 555: val_loss did not improve from 0.01776
#
# Epoch 556: val_loss improved from 0.01776 to 0.01770, saving model to model/model_17-08-2023.h5
#
# Epoch 557: val_loss did not improve from 0.01770
#
# Epoch 558: val_loss did not improve from 0.01770
#
# Epoch 559: val_loss did not improve from 0.01770
#
# Epoch 560: val_loss did not improve from 0.01770
#
# Epoch 561: val_loss improved from 0.01770 to 0.01766, saving model to model/model_17-08-2023.h5
#
# Epoch 562: val_loss did not improve from 0.01766
#
# Epoch 563: val_loss did not improve from 0.01766
#
# Epoch 564: val_loss did not improve from 0.01766
#
# Epoch 565: val_loss did not improve from 0.01766
#
# Epoch 566: val_loss did not improve from 0.01766
#
# Epoch 567: val_loss did not improve from 0.01766
#
# Epoch 568: val_loss did not improve from 0.01766
#
# Epoch 569: val_loss did not improve from 0.01766
#
# Epoch 570: val_loss did not improve from 0.01766
#
# Epoch 571: val_loss did not improve from 0.01766
#
# Epoch 572: val_loss did not improve from 0.01766
#
# Epoch 573: val_loss did not improve from 0.01766
#
# Epoch 574: val_loss did not improve from 0.01766
#
# Epoch 575: val_loss improved from 0.01766 to 0.01759, saving model to model/model_17-08-2023.h5
#
# Epoch 576: val_loss did not improve from 0.01759
#
# Epoch 577: val_loss did not improve from 0.01759
#
# Epoch 578: val_loss did not improve from 0.01759
#
# Epoch 579: val_loss did not improve from 0.01759
#
# Epoch 580: val_loss did not improve from 0.01759
#
# Epoch 581: val_loss improved from 0.01759 to 0.01754, saving model to model/model_17-08-2023.h5
#
# Epoch 582: val_loss did not improve from 0.01754
#
# Epoch 583: val_loss did not improve from 0.01754
#
# Epoch 584: val_loss did not improve from 0.01754
#
# Epoch 585: val_loss did not improve from 0.01754
#
# Epoch 586: val_loss did not improve from 0.01754
#
# Epoch 587: val_loss did not improve from 0.01754
#
# Epoch 588: val_loss did not improve from 0.01754
#
# Epoch 589: val_loss did not improve from 0.01754
#
# Epoch 590: val_loss did not improve from 0.01754
#
# Epoch 591: val_loss improved from 0.01754 to 0.01751, saving model to model/model_17-08-2023.h5
#
# Epoch 592: val_loss did not improve from 0.01751
#
# Epoch 593: val_loss did not improve from 0.01751
#
# Epoch 594: val_loss did not improve from 0.01751
#
# Epoch 595: val_loss did not improve from 0.01751
#
# Epoch 596: val_loss did not improve from 0.01751
#
# Epoch 597: val_loss did not improve from 0.01751
#
# Epoch 598: val_loss did not improve from 0.01751
#
# Epoch 599: val_loss did not improve from 0.01751
#
# Epoch 600: val_loss did not improve from 0.01751
#
# Epoch 601: val_loss did not improve from 0.01751
#
# Epoch 602: val_loss improved from 0.01751 to 0.01749, saving model to model/model_17-08-2023.h5
#
# Epoch 603: val_loss did not improve from 0.01749
#
# Epoch 604: val_loss did not improve from 0.01749
#
# Epoch 605: val_loss did not improve from 0.01749
#
# Epoch 606: val_loss improved from 0.01749 to 0.01743, saving model to model/model_17-08-2023.h5
#
# Epoch 607: val_loss did not improve from 0.01743
#
# Epoch 608: val_loss did not improve from 0.01743
#
# Epoch 609: val_loss did not improve from 0.01743
#
# Epoch 610: val_loss improved from 0.01743 to 0.01738, saving model to model/model_17-08-2023.h5
#
# Epoch 611: val_loss did not improve from 0.01738
#
# Epoch 612: val_loss did not improve from 0.01738
#
# Epoch 613: val_loss did not improve from 0.01738
#
# Epoch 614: val_loss did not improve from 0.01738
#
# Epoch 615: val_loss did not improve from 0.01738
#
# Epoch 616: val_loss did not improve from 0.01738
#
# Epoch 617: val_loss did not improve from 0.01738
#
# Epoch 618: val_loss did not improve from 0.01738
#
# Epoch 619: val_loss did not improve from 0.01738
#
# Epoch 620: val_loss did not improve from 0.01738
#
# Epoch 621: val_loss did not improve from 0.01738
#
# Epoch 622: val_loss did not improve from 0.01738
#
# Epoch 623: val_loss improved from 0.01738 to 0.01727, saving model to model/model_17-08-2023.h5
#
# Epoch 624: val_loss did not improve from 0.01727
#
# Epoch 625: val_loss did not improve from 0.01727
#
# Epoch 626: val_loss did not improve from 0.01727
#
# Epoch 627: val_loss did not improve from 0.01727
#
# Epoch 628: val_loss did not improve from 0.01727
#
# Epoch 629: val_loss improved from 0.01727 to 0.01723, saving model to model/model_17-08-2023.h5
#
# Epoch 630: val_loss did not improve from 0.01723
#
# Epoch 631: val_loss did not improve from 0.01723
#
# Epoch 632: val_loss did not improve from 0.01723
#
# Epoch 633: val_loss did not improve from 0.01723
#
# Epoch 634: val_loss did not improve from 0.01723
#
# Epoch 635: val_loss did not improve from 0.01723
#
# Epoch 636: val_loss did not improve from 0.01723
#
# Epoch 637: val_loss did not improve from 0.01723
#
# Epoch 638: val_loss did not improve from 0.01723
#
# Epoch 639: val_loss did not improve from 0.01723
#
# Epoch 640: val_loss did not improve from 0.01723
#
# Epoch 641: val_loss improved from 0.01723 to 0.01721, saving model to model/model_17-08-2023.h5
#
# Epoch 642: val_loss did not improve from 0.01721
#
# Epoch 643: val_loss did not improve from 0.01721
#
# Epoch 644: val_loss did not improve from 0.01721
#
# Epoch 645: val_loss did not improve from 0.01721
#
# Epoch 646: val_loss did not improve from 0.01721
#
# Epoch 647: val_loss improved from 0.01721 to 0.01708, saving model to model/model_17-08-2023.h5
#
# Epoch 648: val_loss improved from 0.01708 to 0.01705, saving model to model/model_17-08-2023.h5
#
# Epoch 649: val_loss did not improve from 0.01705
#
# Epoch 650: val_loss did not improve from 0.01705
#
# Epoch 651: val_loss did not improve from 0.01705
#
# Epoch 652: val_loss did not improve from 0.01705
#
# Epoch 653: val_loss did not improve from 0.01705
#
# Epoch 654: val_loss did not improve from 0.01705
#
# Epoch 655: val_loss did not improve from 0.01705
#
# Epoch 656: val_loss did not improve from 0.01705
#
# Epoch 657: val_loss did not improve from 0.01705
#
# Epoch 658: val_loss did not improve from 0.01705
#
# Epoch 659: val_loss improved from 0.01705 to 0.01704, saving model to model/model_17-08-2023.h5
#
# Epoch 660: val_loss did not improve from 0.01704
#
# Epoch 661: val_loss did not improve from 0.01704
#
# Epoch 662: val_loss improved from 0.01704 to 0.01700, saving model to model/model_17-08-2023.h5
#
# Epoch 663: val_loss did not improve from 0.01700
#
# Epoch 664: val_loss did not improve from 0.01700
#
# Epoch 665: val_loss did not improve from 0.01700
#
# Epoch 666: val_loss did not improve from 0.01700
#
# Epoch 667: val_loss did not improve from 0.01700
#
# Epoch 668: val_loss did not improve from 0.01700
#
# Epoch 669: val_loss did not improve from 0.01700
#
# Epoch 670: val_loss improved from 0.01700 to 0.01697, saving model to model/model_17-08-2023.h5
#
# Epoch 671: val_loss did not improve from 0.01697
#
# Epoch 672: val_loss did not improve from 0.01697
#
# Epoch 673: val_loss did not improve from 0.01697
#
# Epoch 674: val_loss did not improve from 0.01697
#
# Epoch 675: val_loss did not improve from 0.01697
#
# Epoch 676: val_loss improved from 0.01697 to 0.01689, saving model to model/model_17-08-2023.h5
#
# Epoch 677: val_loss did not improve from 0.01689
#
# Epoch 678: val_loss did not improve from 0.01689
#
# Epoch 679: val_loss did not improve from 0.01689
#
# Epoch 680: val_loss improved from 0.01689 to 0.01684, saving model to model/model_17-08-2023.h5
#
# Epoch 681: val_loss did not improve from 0.01684
#
# Epoch 682: val_loss did not improve from 0.01684
#
# Epoch 683: val_loss did not improve from 0.01684
#
# Epoch 684: val_loss did not improve from 0.01684
#
# Epoch 685: val_loss did not improve from 0.01684
#
# Epoch 686: val_loss did not improve from 0.01684
#
# Epoch 687: val_loss did not improve from 0.01684
#
# Epoch 688: val_loss did not improve from 0.01684
#
# Epoch 689: val_loss did not improve from 0.01684
#
# Epoch 690: val_loss did not improve from 0.01684
#
# Epoch 691: val_loss did not improve from 0.01684
#
# Epoch 692: val_loss did not improve from 0.01684
#
# Epoch 693: val_loss improved from 0.01684 to 0.01682, saving model to model/model_17-08-2023.h5
#
# Epoch 694: val_loss did not improve from 0.01682
#
# Epoch 695: val_loss did not improve from 0.01682
#
# Epoch 696: val_loss did not improve from 0.01682
#
# Epoch 697: val_loss did not improve from 0.01682
#
# Epoch 698: val_loss improved from 0.01682 to 0.01677, saving model to model/model_17-08-2023.h5
#
# Epoch 699: val_loss did not improve from 0.01677
#
# Epoch 700: val_loss did not improve from 0.01677
#
# Epoch 701: val_loss did not improve from 0.01677
#
# Epoch 702: val_loss did not improve from 0.01677
#
# Epoch 703: val_loss did not improve from 0.01677
#
# Epoch 704: val_loss did not improve from 0.01677
#
# Epoch 705: val_loss did not improve from 0.01677
#
# Epoch 706: val_loss did not improve from 0.01677
#
# Epoch 707: val_loss did not improve from 0.01677
#
# Epoch 708: val_loss did not improve from 0.01677
#
# Epoch 709: val_loss improved from 0.01677 to 0.01673, saving model to model/model_17-08-2023.h5
#
# Epoch 710: val_loss did not improve from 0.01673
#
# Epoch 711: val_loss did not improve from 0.01673
#
# Epoch 712: val_loss did not improve from 0.01673
#
# Epoch 713: val_loss did not improve from 0.01673
#
# Epoch 714: val_loss did not improve from 0.01673
#
# Epoch 715: val_loss did not improve from 0.01673
#
# Epoch 716: val_loss did not improve from 0.01673
#
# Epoch 717: val_loss did not improve from 0.01673
#
# Epoch 718: val_loss improved from 0.01673 to 0.01662, saving model to model/model_17-08-2023.h5
#
# Epoch 719: val_loss did not improve from 0.01662
#
# Epoch 720: val_loss did not improve from 0.01662
#
# Epoch 721: val_loss did not improve from 0.01662
#
# Epoch 722: val_loss did not improve from 0.01662
#
# Epoch 723: val_loss did not improve from 0.01662
#
# Epoch 724: val_loss did not improve from 0.01662
#
# Epoch 725: val_loss did not improve from 0.01662
#
# Epoch 726: val_loss improved from 0.01662 to 0.01661, saving model to model/model_17-08-2023.h5
#
# Epoch 727: val_loss did not improve from 0.01661
#
# Epoch 728: val_loss did not improve from 0.01661
#
# Epoch 729: val_loss did not improve from 0.01661
#
# Epoch 730: val_loss did not improve from 0.01661
#
# Epoch 731: val_loss did not improve from 0.01661
#
# Epoch 732: val_loss did not improve from 0.01661
#
# Epoch 733: val_loss did not improve from 0.01661
#
# Epoch 734: val_loss did not improve from 0.01661
#
# Epoch 735: val_loss did not improve from 0.01661
#
# Epoch 736: val_loss did not improve from 0.01661
#
# Epoch 737: val_loss improved from 0.01661 to 0.01657, saving model to model/model_17-08-2023.h5
#
# Epoch 738: val_loss improved from 0.01657 to 0.01655, saving model to model/model_17-08-2023.h5
#
# Epoch 739: val_loss did not improve from 0.01655
#
# Epoch 740: val_loss did not improve from 0.01655
#
# Epoch 741: val_loss did not improve from 0.01655
#
# Epoch 742: val_loss did not improve from 0.01655
#
# Epoch 743: val_loss did not improve from 0.01655
#
# ...
#
# Epoch 2254: val_loss did not improve from 0.01223
#
# Epoch 2255: val_loss did not improve from 0.01223
#
# Epoch 2256: val_loss did not improve from 0.01223
#
# Epoch 2257: val_loss did not improve from 0.01223
#
# Epoch 2258: val_loss did not improve from 0.01223
#
# Epoch 2259: val_loss did not improve from 0.01223
#
# Epoch 2260: val_loss did not improve from 0.01223
#
# Epoch 2261: val_loss did not improve from 0.01223
#
# Epoch 2262: val_loss did not improve from 0.01223
#
# Epoch 2263: val_loss did not improve from 0.01223
#
# Epoch 2264: val_loss did not improve from 0.01223
#
# Epoch 2265: val_loss did not improve from 0.01223
#
# Epoch 2266: val_loss did not improve from 0.01223
#
# Epoch 2267: val_loss did not improve from 0.01223
#
# Epoch 2268: val_loss did not improve from 0.01223
#
# Epoch 2269: val_loss did not improve from 0.01223
#
# Epoch 2270: val_loss did not improve from 0.01223
#
# Epoch 2271: val_loss did not improve from 0.01223
#
# Epoch 2272: val_loss did not improve from 0.01223
#
# Epoch 2273: val_loss did not improve from 0.01223
#
# Epoch 2274: val_loss did not improve from 0.01223
#
# Epoch 2275: val_loss did not improve from 0.01223
#
# Epoch 2276: val_loss did not improve from 0.01223
#
# Epoch 2277: val_loss did not improve from 0.01223
#
# Epoch 2278: val_loss did not improve from 0.01223
#
# Epoch 2279: val_loss improved from 0.01223 to 0.01222, saving model to model/model_17-08-2023.h5
#
# Epoch 2280: val_loss improved from 0.01222 to 0.01217, saving model to model/model_17-08-2023.h5
#
# Epoch 2281: val_loss did not improve from 0.01217
#
# Epoch 2282: val_loss did not improve from 0.01217
#
# Epoch 2283: val_loss improved from 0.01217 to 0.01216, saving model to model/model_17-08-2023.h5
#
# Epoch 2284: val_loss improved from 0.01216 to 0.01215, saving model to model/model_17-08-2023.h5
#
# Epoch 2285: val_loss did not improve from 0.01215
#
# Epoch 2286: val_loss improved from 0.01215 to 0.01215, saving model to model/model_17-08-2023.h5
#
# Epoch 2287: val_loss did not improve from 0.01215
#
# Epoch 2288: val_loss did not improve from 0.01215
#
# Epoch 2289: val_loss did not improve from 0.01215
#
# Epoch 2290: val_loss did not improve from 0.01215
#
# Epoch 2291: val_loss did not improve from 0.01215
#
# Epoch 2292: val_loss did not improve from 0.01215
#
# Epoch 2293: val_loss improved from 0.01215 to 0.01213, saving model to model/model_17-08-2023.h5
#
# Epoch 2294: val_loss did not improve from 0.01213
#
# Epoch 2295: val_loss did not improve from 0.01213
#
# Epoch 2296: val_loss did not improve from 0.01213
#
# Epoch 2297: val_loss did not improve from 0.01213
#
# Epoch 2298: val_loss did not improve from 0.01213
#
# Epoch 2299: val_loss did not improve from 0.01213
#
# Epoch 2300: val_loss did not improve from 0.01213
#
# Epoch 2301: val_loss did not improve from 0.01213
#
# Epoch 2302: val_loss did not improve from 0.01213
#
# Epoch 2303: val_loss did not improve from 0.01213
#
# Epoch 2304: val_loss did not improve from 0.01213
#
# Epoch 2305: val_loss did not improve from 0.01213
#
# Epoch 2306: val_loss did not improve from 0.01213
#
# Epoch 2307: val_loss did not improve from 0.01213
#
# Epoch 2308: val_loss did not improve from 0.01213
#
# Epoch 2309: val_loss did not improve from 0.01213
#
# Epoch 2310: val_loss did not improve from 0.01213
#
# Epoch 2311: val_loss did not improve from 0.01213
#
# Epoch 2312: val_loss did not improve from 0.01213
#
# Epoch 2313: val_loss improved from 0.01213 to 0.01211, saving model to model/model_17-08-2023.h5
#
# Epoch 2314: val_loss did not improve from 0.01211
#
# Epoch 2315: val_loss did not improve from 0.01211
#
# Epoch 2316: val_loss did not improve from 0.01211
#
# Epoch 2317: val_loss did not improve from 0.01211
#
# Epoch 2318: val_loss did not improve from 0.01211
#
# Epoch 2319: val_loss improved from 0.01211 to 0.01207, saving model to model/model_17-08-2023.h5
#
# Epoch 2320: val_loss did not improve from 0.01207
#
# Epoch 2321: val_loss did not improve from 0.01207
#
# Epoch 2322: val_loss did not improve from 0.01207
#
# Epoch 2323: val_loss did not improve from 0.01207
#
# Epoch 2324: val_loss did not improve from 0.01207
#
# Epoch 2325: val_loss did not improve from 0.01207
#
# Epoch 2326: val_loss did not improve from 0.01207
#
# Epoch 2327: val_loss did not improve from 0.01207
#
# Epoch 2328: val_loss did not improve from 0.01207
#
# Epoch 2329: val_loss did not improve from 0.01207
#
# Epoch 2330: val_loss did not improve from 0.01207
#
# Epoch 2331: val_loss did not improve from 0.01207
#
# Epoch 2332: val_loss did not improve from 0.01207
#
# Epoch 2333: val_loss did not improve from 0.01207
#
# Epoch 2334: val_loss did not improve from 0.01207
#
# Epoch 2335: val_loss did not improve from 0.01207
#
# Epoch 2336: val_loss did not improve from 0.01207
#
# Epoch 2337: val_loss did not improve from 0.01207
#
# Epoch 2338: val_loss did not improve from 0.01207
#
# Epoch 2339: val_loss did not improve from 0.01207
#
# Epoch 2340: val_loss did not improve from 0.01207
#
# Epoch 2341: val_loss did not improve from 0.01207
#
# Epoch 2342: val_loss did not improve from 0.01207
#
# Epoch 2343: val_loss did not improve from 0.01207
#
# Epoch 2344: val_loss did not improve from 0.01207
#
# Epoch 2345: val_loss did not improve from 0.01207
#
# Epoch 2346: val_loss did not improve from 0.01207
#
# Epoch 2347: val_loss did not improve from 0.01207
#
# Epoch 2348: val_loss did not improve from 0.01207
#
# Epoch 2349: val_loss did not improve from 0.01207
#
# Epoch 2350: val_loss did not improve from 0.01207
#
# Epoch 2351: val_loss did not improve from 0.01207
#
# Epoch 2352: val_loss did not improve from 0.01207
#
# Epoch 2353: val_loss did not improve from 0.01207
#
# Epoch 2354: val_loss did not improve from 0.01207
#
# Epoch 2355: val_loss did not improve from 0.01207
#
# Epoch 2356: val_loss did not improve from 0.01207
#
# Epoch 2357: val_loss did not improve from 0.01207
#
# Epoch 2358: val_loss did not improve from 0.01207
#
# Epoch 2359: val_loss did not improve from 0.01207
#
# Epoch 2360: val_loss improved from 0.01207 to 0.01205, saving model to model/model_17-08-2023.h5
#
# Epoch 2361: val_loss did not improve from 0.01205
#
# Epoch 2362: val_loss did not improve from 0.01205
#
# Epoch 2363: val_loss did not improve from 0.01205
#
# Epoch 2364: val_loss did not improve from 0.01205
#
# Epoch 2365: val_loss did not improve from 0.01205
#
# Epoch 2366: val_loss did not improve from 0.01205
#
# Epoch 2367: val_loss did not improve from 0.01205
#
# Epoch 2368: val_loss improved from 0.01205 to 0.01205, saving model to model/model_17-08-2023.h5
#
# Epoch 2369: val_loss did not improve from 0.01205
#
# Epoch 2370: val_loss did not improve from 0.01205
#
# Epoch 2371: val_loss did not improve from 0.01205
#
# Epoch 2372: val_loss did not improve from 0.01205
#
# Epoch 2373: val_loss did not improve from 0.01205
#
# Epoch 2374: val_loss did not improve from 0.01205
#
# Epoch 2375: val_loss did not improve from 0.01205
#
# Epoch 2376: val_loss did not improve from 0.01205
#
# Epoch 2377: val_loss did not improve from 0.01205
#
# Epoch 2378: val_loss did not improve from 0.01205
#
# Epoch 2379: val_loss did not improve from 0.01205
#
# Epoch 2380: val_loss did not improve from 0.01205
#
# Epoch 2381: val_loss did not improve from 0.01205
#
# Epoch 2382: val_loss did not improve from 0.01205
#
# Epoch 2383: val_loss did not improve from 0.01205
#
# Epoch 2384: val_loss did not improve from 0.01205
#
# Epoch 2385: val_loss did not improve from 0.01205
#
# Epoch 2386: val_loss did not improve from 0.01205
#
# Epoch 2387: val_loss improved from 0.01205 to 0.01205, saving model to model/model_17-08-2023.h5
#
# Epoch 2388: val_loss did not improve from 0.01205
#
# Epoch 2389: val_loss did not improve from 0.01205
#
# Epoch 2390: val_loss did not improve from 0.01205
#
# Epoch 2391: val_loss did not improve from 0.01205
#
# Epoch 2392: val_loss did not improve from 0.01205
#
# Epoch 2393: val_loss did not improve from 0.01205
#
# Epoch 2394: val_loss did not improve from 0.01205
#
# Epoch 2395: val_loss did not improve from 0.01205
#
# Epoch 2396: val_loss improved from 0.01205 to 0.01199, saving model to model/model_17-08-2023.h5
#
# Epoch 2397: val_loss did not improve from 0.01199
#
# Epoch 2398: val_loss did not improve from 0.01199
#
# Epoch 2399: val_loss did not improve from 0.01199
#
# Epoch 2400: val_loss did not improve from 0.01199
#
# Epoch 2401: val_loss did not improve from 0.01199
#
# Epoch 2402: val_loss did not improve from 0.01199
#
# Epoch 2403: val_loss did not improve from 0.01199
#
# Epoch 2404: val_loss improved from 0.01199 to 0.01198, saving model to model/model_17-08-2023.h5
#
# Epoch 2405: val_loss did not improve from 0.01198
#
# Epoch 2406: val_loss did not improve from 0.01198
#
# Epoch 2407: val_loss did not improve from 0.01198
#
# Epoch 2408: val_loss did not improve from 0.01198
#
# Epoch 2409: val_loss did not improve from 0.01198
#
# Epoch 2410: val_loss did not improve from 0.01198
#
# Epoch 2411: val_loss did not improve from 0.01198
#
# Epoch 2412: val_loss did not improve from 0.01198
#
# Epoch 2413: val_loss did not improve from 0.01198
#
# Epoch 2414: val_loss did not improve from 0.01198
#
# Epoch 2415: val_loss did not improve from 0.01198
#
# Epoch 2416: val_loss did not improve from 0.01198
#
# Epoch 2417: val_loss did not improve from 0.01198
#
# Epoch 2418: val_loss did not improve from 0.01198
#
# Epoch 2419: val_loss did not improve from 0.01198
#
# Epoch 2420: val_loss did not improve from 0.01198
#
# Epoch 2421: val_loss did not improve from 0.01198
#
# Epoch 2422: val_loss did not improve from 0.01198
#
# Epoch 2423: val_loss did not improve from 0.01198
#
# Epoch 2424: val_loss improved from 0.01198 to 0.01192, saving model to model/model_17-08-2023.h5
#
# Epoch 2425: val_loss did not improve from 0.01192
#
# Epoch 2426: val_loss did not improve from 0.01192
#
# Epoch 2427: val_loss did not improve from 0.01192
#
# Epoch 2428: val_loss did not improve from 0.01192
#
# Epoch 2429: val_loss did not improve from 0.01192
#
# Epoch 2430: val_loss did not improve from 0.01192
#
# Epoch 2431: val_loss did not improve from 0.01192
#
# Epoch 2432: val_loss did not improve from 0.01192
#
# Epoch 2433: val_loss did not improve from 0.01192
#
# Epoch 2434: val_loss did not improve from 0.01192
#
# Epoch 2435: val_loss did not improve from 0.01192
#
# Epoch 2436: val_loss did not improve from 0.01192
#
# Epoch 2437: val_loss did not improve from 0.01192
#
# Epoch 2438: val_loss did not improve from 0.01192
#
# Epoch 2439: val_loss did not improve from 0.01192
#
# Epoch 2440: val_loss did not improve from 0.01192
#
# Epoch 2441: val_loss did not improve from 0.01192
#
# Epoch 2442: val_loss did not improve from 0.01192
#
# Epoch 2443: val_loss did not improve from 0.01192
#
# Epoch 2444: val_loss did not improve from 0.01192
#
# Epoch 2445: val_loss did not improve from 0.01192
#
# Epoch 2446: val_loss improved from 0.01192 to 0.01191, saving model to model/model_17-08-2023.h5
#
# Epoch 2447: val_loss did not improve from 0.01191
#
# Epoch 2448: val_loss did not improve from 0.01191
#
# Epoch 2449: val_loss did not improve from 0.01191
#
# Epoch 2450: val_loss did not improve from 0.01191
#
# Epoch 2451: val_loss did not improve from 0.01191
#
# Epoch 2452: val_loss did not improve from 0.01191
#
# Epoch 2453: val_loss did not improve from 0.01191
#
# Epoch 2454: val_loss did not improve from 0.01191
#
# Epoch 2455: val_loss did not improve from 0.01191
#
# Epoch 2456: val_loss did not improve from 0.01191
#
# Epoch 2457: val_loss did not improve from 0.01191
#
# Epoch 2458: val_loss did not improve from 0.01191
#
# Epoch 2459: val_loss did not improve from 0.01191
#
# Epoch 2460: val_loss did not improve from 0.01191
#
# Epoch 2461: val_loss did not improve from 0.01191
#
# Epoch 2462: val_loss did not improve from 0.01191
#
# Epoch 2463: val_loss did not improve from 0.01191
#
# Epoch 2464: val_loss did not improve from 0.01191
#
# Epoch 2465: val_loss did not improve from 0.01191
#
# Epoch 2466: val_loss did not improve from 0.01191
#
# Epoch 2467: val_loss did not improve from 0.01191
#
# Epoch 2468: val_loss did not improve from 0.01191
#
# Epoch 2469: val_loss did not improve from 0.01191
#
# Epoch 2470: val_loss did not improve from 0.01191
#
# Epoch 2471: val_loss did not improve from 0.01191
#
# Epoch 2472: val_loss did not improve from 0.01191
#
# Epoch 2473: val_loss did not improve from 0.01191
#
# Epoch 2474: val_loss did not improve from 0.01191
#
# Epoch 2475: val_loss did not improve from 0.01191
#
# Epoch 2476: val_loss did not improve from 0.01191
#
# Epoch 2477: val_loss did not improve from 0.01191
#
# Epoch 2478: val_loss did not improve from 0.01191
#
# Epoch 2479: val_loss did not improve from 0.01191
#
# Epoch 2480: val_loss did not improve from 0.01191
#
# Epoch 2481: val_loss did not improve from 0.01191
#
# Epoch 2482: val_loss did not improve from 0.01191
#
# Epoch 2483: val_loss did not improve from 0.01191
#
# Epoch 2484: val_loss did not improve from 0.01191
#
# Epoch 2485: val_loss did not improve from 0.01191
#
# Epoch 2486: val_loss did not improve from 0.01191
#
# Epoch 2487: val_loss did not improve from 0.01191
#
# Epoch 2488: val_loss did not improve from 0.01191
#
# Epoch 2489: val_loss did not improve from 0.01191
#
# Epoch 2490: val_loss did not improve from 0.01191
#
# Epoch 2491: val_loss did not improve from 0.01191
#
# Epoch 2492: val_loss did not improve from 0.01191
#
# Epoch 2493: val_loss improved from 0.01191 to 0.01189, saving model to model/model_17-08-2023.h5
#
# Epoch 2494: val_loss did not improve from 0.01189
#
# Epoch 2495: val_loss did not improve from 0.01189
#
# Epoch 2496: val_loss did not improve from 0.01189
#
# Epoch 2497: val_loss did not improve from 0.01189
#
# Epoch 2498: val_loss improved from 0.01189 to 0.01187, saving model to model/model_17-08-2023.h5
#
# Epoch 2499: val_loss did not improve from 0.01187
#
# Epoch 2500: val_loss did not improve from 0.01187
#
# Epoch 2501: val_loss did not improve from 0.01187
#
# Epoch 2502: val_loss did not improve from 0.01187
#
# Epoch 2503: val_loss did not improve from 0.01187
#
# Epoch 2504: val_loss did not improve from 0.01187
#
# Epoch 2505: val_loss did not improve from 0.01187
#
# Epoch 2506: val_loss did not improve from 0.01187
#
# Epoch 2507: val_loss did not improve from 0.01187
#
# Epoch 2508: val_loss did not improve from 0.01187
#
# Epoch 2509: val_loss did not improve from 0.01187
#
# Epoch 2510: val_loss did not improve from 0.01187
#
# Epoch 2511: val_loss did not improve from 0.01187
#
# Epoch 2512: val_loss did not improve from 0.01187
#
# Epoch 2513: val_loss did not improve from 0.01187
#
# Epoch 2514: val_loss did not improve from 0.01187
#
# Epoch 2515: val_loss did not improve from 0.01187
#
# Epoch 2516: val_loss did not improve from 0.01187
#
# Epoch 2517: val_loss did not improve from 0.01187
#
# Epoch 2518: val_loss did not improve from 0.01187
#
# Epoch 2519: val_loss did not improve from 0.01187
#
# Epoch 2520: val_loss did not improve from 0.01187
#
# Epoch 2521: val_loss did not improve from 0.01187
#
# Epoch 2522: val_loss did not improve from 0.01187
#
# Epoch 2523: val_loss did not improve from 0.01187
#
# Epoch 2524: val_loss did not improve from 0.01187
#
# Epoch 2525: val_loss did not improve from 0.01187
#
# Epoch 2526: val_loss did not improve from 0.01187
#
# Epoch 2527: val_loss did not improve from 0.01187
#
# Epoch 2528: val_loss did not improve from 0.01187
#
# Epoch 2529: val_loss did not improve from 0.01187
#
# Epoch 2530: val_loss did not improve from 0.01187
#
# Epoch 2531: val_loss did not improve from 0.01187
#
# Epoch 2532: val_loss did not improve from 0.01187
#
# Epoch 2533: val_loss did not improve from 0.01187
#
# Epoch 2534: val_loss did not improve from 0.01187
#
# Epoch 2535: val_loss did not improve from 0.01187
#
# Epoch 2536: val_loss did not improve from 0.01187
#
# Epoch 2537: val_loss did not improve from 0.01187
#
# Epoch 2538: val_loss did not improve from 0.01187
#
# Epoch 2539: val_loss did not improve from 0.01187
#
# Epoch 2540: val_loss did not improve from 0.01187
#
# Epoch 2541: val_loss did not improve from 0.01187
#
# Epoch 2542: val_loss did not improve from 0.01187
#
# Epoch 2543: val_loss did not improve from 0.01187
#
# Epoch 2544: val_loss did not improve from 0.01187
#
# Epoch 2545: val_loss did not improve from 0.01187
#
# Epoch 2546: val_loss did not improve from 0.01187
#
# Epoch 2547: val_loss did not improve from 0.01187
#
# Epoch 2548: val_loss did not improve from 0.01187
# Epoch 2548: early stopping
# 1875/1875 [==============================] - 1s 570us/step
# time: 3h 19min 16s (started: 2023-08-19 21:33:23 +02:00)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))
ax1.plot(h.history["loss"], label="Training Loss")
ax1.plot(h.history["val_loss"], label="Validation Loss")
ax1.semilogy()

ax2.plot(h.history['mape'], label="Training MAPE")
ax2.plot(h.history["val_mape"], label="Validation MAPE")

ax1.set_ylabel("Loss [MSE]")
ax2.set_ylabel("Error [MAPE]")

for ax in [ax1, ax2]:
    ax.minorticks_on()
    ax.semilogy()
    ax.legend(frameon=False)
    ax.set_xlabel("Number of Epochs")
    # ax.set_yticks([0.01, 0.05, 0.1, 0.5])
    ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.savefig("/work/bb1070/b382177/mie/icon/17-08-2023/figs/opt_epochs.png", bbox_inches="tight")
plt.show()
# Out:
# time: 939 ms (started: 2023-08-20 00:52:39 +02:00)

# %%
test_y[out_col] = qt.inverse_transform(test_y)
pred_y[out_col] = qt.inverse_transform(pred_y)
# Out:
# time: 66.4 ms (started: 2023-08-20 00:52:40 +02:00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(23, 7))
for col, ax in zip(y.columns, axes):
    ntest = test_y[col]
    npred = pred_y[col]
        
    corr = np.corrcoef(ntest, npred)[0,1]
    r2 = r2_score(ntest, npred)
    
    x1 = test_y[col]
    y1 = pred_y[col]    

    x1 = (mx[col] - mn[col]) * x1 + mn[col]
    y1 = (mx[col] - mn[col]) * y1 + mn[col]
        
    ax.scatter(x1, y1)
    ax.scatter(x1, x1)
    ax.set_title('%s [$R^2$=%0.3f]'%(col, r2), fontsize=20)
    ax.set_xlabel('Mie', fontsize=20)
    ax.minorticks_on()
    ax.tick_params(labelsize=18)
axes[0].set_ylabel('MieAI', fontsize=20)
plt.savefig("/work/bb1070/b382177/mie/icon/17-08-2023/figs/mlp_accuracy_stats.png", bbox_inches="tight")
plt.show()
# Out:
# time: 2.85 s (started: 2023-08-20 00:52:40 +02:00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(19, 6), sharey=True)
axes = axes.flatten()
for i, (col, ax) in enumerate(zip(y.columns, axes)):
    ntest = test_y[col]
    npred = pred_y[col]  
    
    x1 = test_y[col]
    y1 = pred_y[col]  
    
    x1 = (mx[col] - mn[col]) * x1 + mn[col]
    y1 = (mx[col] - mn[col]) * y1 + mn[col]
    
    corr = np.corrcoef(x1, y1)[0,1]    
    error = 100 * (y1 - x1) / x1   
    
    ax.hist(error, bins=np.arange(-20, 21, 1), density=True, color='blue')
    # ax.hist(error, bins=100, density=True)
    
    # ax.set_title('%s [R=%0.3f]'%(col, corr), fontsize=20)
    ax.set_title('%s'%(col), fontsize=20, y=0.9)
    ax.set_xlabel('Error [%]', fontsize=20)
    ax.set_ylabel('Density', fontsize=20)
    if i!=0:
        ax.set_ylabel('', fontsize=20)
        
    if i!=1:
        ax.set_xlabel('', fontsize=20)
        
    ax.minorticks_on()
    ax.set_yticks(np.arange(0, 0.25, 0.05))
    ax.tick_params(labelsize=16)
    
plt.subplots_adjust(hspace=0.01, wspace=0.05)
plt.savefig('/work/bb1070/b382177/mie/icon/17-08-2023/figs/mlp_error_ana.png', bbox_inches='tight')
plt.show()
# Out:
# time: 883 ms (started: 2023-08-20 00:52:43 +02:00)

# %%
model.save('/work/bb1070/b382177/mie/icon/17-08-2023/model/model_17-08-2023.h5')
# Out:
# time: 50.4 ms (started: 2023-08-20 00:52:44 +02:00)

# %%
joblib.dump(qt, '/work/bb1070/b382177/mie/icon/17-08-2023/model/transformer_17-08-2023.pkl')
# Out:
# ['/work/bb1070/b382177/mie/icon/17-08-2023/model/transformer_17-08-2023.pkl']
# time: 33.9 ms (started: 2023-08-20 00:52:44 +02:00)

# %%
lmodel = tf.keras.models.load_model('/work/bb1070/b382177/mie/icon/17-08-2023/model/model_17-08-2023.h5')
# Out:
# time: 104 ms (started: 2023-08-20 00:52:44 +02:00)
