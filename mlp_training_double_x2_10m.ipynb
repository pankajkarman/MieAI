# %%
# %load_ext autotime
# Out:
# time: 139 µs (started: 2023-07-24 13:39:42 +02:00)

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# time: 244 µs (started: 2023-07-24 13:39:42 +02:00)

# %%
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Activation 
from tensorflow.keras.callbacks import ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau, EarlyStopping
# Out:
# 2023-07-24 13:39:44.525911: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 13:39:44.823527: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-24 13:39:44.823557: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-24 13:39:46.628401: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-07-24 13:39:46.628848: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-07-24 13:39:46.628856: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# time: 6.87 s (started: 2023-07-24 13:39:42 +02:00)

# %%
# from kerastuner.tuners import RandomSearch
from net import create_model, normalize, normalize1
# Out:
# time: 21.4 ms (started: 2023-07-24 13:39:49 +02:00)

# %%
columns = ['Extinction', 'Scattering', 'SSA', 'Asym', 'coating', 'core_dia', 'n_core', 'k_core', 'n_shell', 'k_shell', 'density', 'lambda']
df = pd.read_csv('/work/bb1070/b382177/mie/icon/24-07-2023/mie_all.csv', index_col=0).sort_index()
df = df[columns].dropna().astype('float').drop_duplicates()
df['x'] = np.pi * df['core_dia'] / df['lambda']
df
# Out:
#           Extinction  Scattering       SSA      Asym  coating  core_dia  \
# 0           0.072795    0.002253  0.030951  0.019297      0.0      10.0
# 2           0.034139    0.000141  0.004118  0.004843      0.0      10.0
# 8           0.007768    0.000024  0.003152  0.002135      0.0      10.0
# 11          0.003332    0.000005  0.001404  0.000946      0.0      10.0
# 11          0.003332    0.000005  0.001404  0.000946      0.0      10.0
# ...              ...         ...       ...       ...      ...       ...
# 44527776    0.844114    0.108977  0.129103  0.083386      0.4   10000.0
# 44527837    1.117326    0.202738  0.181449  0.117843      0.4   11000.0
# 44527839    0.886265    0.122657  0.138398  0.089080      0.4   11000.0
# 44527902    0.819451    0.106342  0.129773  0.083984      0.4   12000.0
# 44527903    0.671211    0.068711  0.102369  0.067859      0.4   12000.0
#
#            n_core    k_core   n_shell       k_shell  density    lambda  \
# 0         1.48600  0.106100  1.464000  2.630000e-07      2.6     100.0
# 2         1.48600  0.106100  1.396000  1.100000e-07      2.6     200.0
# 8         1.46300  0.035900  1.349000  1.600000e-08      2.6     300.0
# 11        1.45504  0.023075  1.336727  1.353750e-09      2.6     450.0
# 11        1.45504  0.023075  1.336727  1.353750e-09      2.6     450.0
# ...           ...       ...       ...           ...      ...       ...
# 44527776  1.61350  0.648098  2.017500  7.225000e-01      1.7   75000.0
# 44527837  1.61350  0.648098  2.015000  7.250000e-01      1.7   70000.0
# 44527839  1.61350  0.648098  2.020000  7.200000e-01      1.7   80000.0
# 44527902  1.61350  0.648098  2.020000  6.850000e-01      1.7   90000.0
# 44527903  1.61350  0.648098  2.020000  6.500000e-01      1.7  100000.0
#
#                  x
# 0         0.314159
# 2         0.157080
# 8         0.104720
# 11        0.069813
# 11        0.069813
# ...            ...
# 44527776  0.418879
# 44527837  0.493679
# 44527839  0.431969
# 44527902  0.418879
# 44527903  0.376991
#
# [9686070 rows x 13 columns]
# time: 51.3 s (started: 2023-07-24 13:39:49 +02:00)

# %%
mx = df.max()
mn = df.min()
pd.concat([pd.DataFrame(mx), pd.DataFrame(mn)], axis=1).to_csv('/work/bb1070/b382177/mie/icon/24-07-2023/mlp_min_max_x2.csv')
# Out:
# time: 320 ms (started: 2023-07-24 13:40:40 +02:00)

# %%
df1 = df[df.x > 0.5]
df1
# Out:
#           Extinction  Scattering       SSA      Asym  coating  core_dia  \
# 192         0.110201    0.016399  0.148813  0.053173     0.00      40.0
# 249         0.536998    0.230364  0.428984  0.226929     0.00      50.0
# 249         0.536998    0.230364  0.428984  0.226929     0.00      50.0
# 254         0.163354    0.039507  0.241849  0.083190     0.00      50.0
# 312         0.429602    0.161829  0.376696  0.179406     0.00      60.0
# ...              ...         ...       ...       ...      ...       ...
# 40204573    2.043812    1.162208  0.568647  0.574923     0.36   11000.0
# 40204574    1.209879    0.585066  0.483573  0.313111     0.36   11000.0
# 40204576    0.488016    0.155189  0.318000  0.123113     0.36   11000.0
# 40204584    2.048849    1.135797  0.554358  0.938225     0.36   12000.0
# 40204585    2.050470    1.136432  0.554230  0.938228     0.36   12000.0
#
#             n_core    k_core  n_shell       k_shell  density   lambda  \
# 192       1.476800  0.078020   1.3688  4.880000e-08      2.6    240.0
# 249       1.486000  0.106100   1.4300  1.865000e-07      2.6    150.0
# 249       1.486000  0.106100   1.4300  1.865000e-07      2.6    150.0
# 254       1.476800  0.078020   1.3688  4.880000e-08      2.6    240.0
# 312       1.486000  0.106100   1.3960  1.100000e-07      2.6    200.0
# ...            ...       ...      ...           ...      ...      ...
# 40204573  1.737322  0.323523   1.6200  5.000000e-02      1.7  30000.0
# 40204574  1.737109  0.368913   1.6200  5.000000e-02      1.7  40000.0
# 40204576  1.750163  0.352284   1.6200  5.000000e-02      1.7  60000.0
# 40204584  1.471186  0.029172   1.6200  3.700000e-02      1.7    200.0
# 40204585  1.469323  0.027791   1.6200  3.700000e-02      1.7    210.0
#
#                    x
# 192         0.523599
# 249         1.047198
# 249         1.047198
# 254         0.654498
# 312         0.942478
# ...              ...
# 40204573    1.151917
# 40204574    0.863938
# 40204576    0.575959
# 40204584  188.495559
# 40204585  179.519580
#
# [5531457 rows x 13 columns]
# time: 882 ms (started: 2023-07-24 13:40:40 +02:00)

# %%
df_shuffled = df1.sample(frac=1, random_state=40).reset_index(drop=True)
df_shuffled = normalize1(df_shuffled)

out_col = ["Extinction", "Scattering", "Asym"]
in_col = ['coating', 'x', 'n_core', 'k_core', 'n_shell', 'k_shell']

y = df_shuffled[out_col]
x = df_shuffled[in_col]

split = 0.8
train_size = int(split * len(x))
train_x = x.iloc[:train_size, :].reset_index(drop=True)
train_y = y.iloc[:train_size, :].reset_index(drop=True)
test_x = x.iloc[train_size:, :].reset_index(drop=True)
test_y = y.iloc[train_size:, :].reset_index(drop=True)
train_y
# Out:
#          Extinction  Scattering      Asym
# 0          0.450873    0.250176  0.954549
# 1          0.451206    0.244508  0.975758
# 2          0.454677    0.248138  0.841665
# 3          0.528779    0.272999  0.932618
# 4          0.449394    0.246708  0.963596
# ...             ...         ...       ...
# 4425160    0.152194    0.128570  0.447660
# 4425161    0.464915    0.248701  0.976729
# 4425162    0.587328    0.285657  0.608381
# 4425163    0.468391    0.247999  0.980577
# 4425164    0.453044    0.255870  0.938459
#
# [4425165 rows x 3 columns]
# time: 1.5 s (started: 2023-07-24 13:40:41 +02:00)

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)

model = create_model(
    6,
    3,
    hidden=[16, 32, 32, 16],
    # dropout=[0.1, 0.3, 0.3, 0],
    dropout=[0, 0, 0, 0, 0],
    # activation=["relu", "tanh", "tanh", "tanh"],
    activation=["gelu", "gelu", "gelu", 'gelu', 'gelu'],
    # activation=["relu", "relu", "relu", 'relu'],
    loss="mse",
    optimizer=opt,
    metrics=['mse', 'mae', 'mape']
)

mc = ModelCheckpoint('model/model_24-07-2023_x2.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True, save_weights_only=False)
es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=10)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)
tnan = TerminateOnNaN()
callbacks = [es, mc, tnan, rlr]

h = model.fit(
    train_x,
    train_y,
    epochs=100,
    batch_size=500,
    verbose=0,
    validation_split=0.2,
    callbacks=callbacks,
    shuffle=True
)

pred_y = model.predict(test_x)
pred_y = pd.DataFrame(pred_y, columns=out_col)
# Out:
# Input shape: (6,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 16)                112
#
#  dropout (Dropout)           (None, 16)                0
# 2023-07-24 13:40:43.189640: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-07-24 13:40:43.189677: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-07-24 13:40:43.189695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (l40007.lvt.dkrz.de): /proc/driver/nvidia/version does not exist
# 2023-07-24 13:40:43.190625: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
#  batch_normalization (BatchN  (None, 16)               64
#  ormalization)
#
#  hidden_layer_2 (Dense)      (None, 32)                544
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  hidden_layer_3 (Dense)      (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  hidden_layer_4 (Dense)      (None, 16)                528
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  output_layer (Dense)        (None, 3)                 51
#
# =================================================================
# Total params: 2,675
# Trainable params: 2,483
# Non-trainable params: 192
# _________________________________________________________________
# None
#
# Epoch 1: val_loss improved from inf to 0.00370, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 2: val_loss did not improve from 0.00370
#
# Epoch 3: val_loss did not improve from 0.00370
#
# Epoch 4: val_loss did not improve from 0.00370
#
# Epoch 5: val_loss improved from 0.00370 to 0.00153, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 6: val_loss improved from 0.00153 to 0.00052, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 7: val_loss did not improve from 0.00052
#
# Epoch 8: val_loss did not improve from 0.00052
#
# Epoch 9: val_loss did not improve from 0.00052
#
# Epoch 10: val_loss did not improve from 0.00052
#
# Epoch 11: val_loss improved from 0.00052 to 0.00027, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 12: val_loss did not improve from 0.00027
#
# Epoch 13: val_loss did not improve from 0.00027
#
# Epoch 14: val_loss improved from 0.00027 to 0.00018, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 15: val_loss did not improve from 0.00018
#
# Epoch 16: val_loss did not improve from 0.00018
#
# Epoch 17: val_loss did not improve from 0.00018
#
# Epoch 18: val_loss did not improve from 0.00018
#
# Epoch 19: val_loss did not improve from 0.00018
#
# Epoch 20: val_loss did not improve from 0.00018
#
# Epoch 21: val_loss did not improve from 0.00018
#
# Epoch 22: val_loss improved from 0.00018 to 0.00009, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 23: val_loss did not improve from 0.00009
#
# Epoch 24: val_loss improved from 0.00009 to 0.00009, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 25: val_loss did not improve from 0.00009
#
# Epoch 26: val_loss did not improve from 0.00009
#
# Epoch 27: val_loss did not improve from 0.00009
#
# Epoch 28: val_loss did not improve from 0.00009
#
# Epoch 29: val_loss did not improve from 0.00009
#
# Epoch 30: val_loss improved from 0.00009 to 0.00009, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 31: val_loss did not improve from 0.00009
#
# Epoch 32: val_loss improved from 0.00009 to 0.00009, saving model to model/model_24-07-2023_x2.h5
#
# Epoch 33: val_loss did not improve from 0.00009
#
# Epoch 34: val_loss did not improve from 0.00009
#
# Epoch 35: val_loss did not improve from 0.00009
#
# Epoch 36: val_loss did not improve from 0.00009
#
# Epoch 37: val_loss did not improve from 0.00009
#
# Epoch 38: val_loss did not improve from 0.00009
#
# Epoch 39: val_loss did not improve from 0.00009
#
# Epoch 40: val_loss did not improve from 0.00009
#
# Epoch 41: val_loss did not improve from 0.00009
#
# Epoch 42: val_loss did not improve from 0.00009
# Epoch 42: early stopping
# 34572/34572 [==============================] - 21s 594us/step
# time: 10min 36s (started: 2023-07-24 13:40:43 +02:00)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))
ax1.plot(h.history["loss"], label="Training Loss")
ax1.plot(h.history["val_loss"], label="Validation Loss")
ax1.semilogy()

ax2.plot(h.history['mae'], label="Training MAE")
ax2.plot(h.history["val_mae"], label="Validation MAE")

ax1.set_ylabel("Loss [MSE]")
ax2.set_ylabel("Error [MAE]")

for ax in [ax1, ax2]:
    ax.minorticks_on()
    ax.semilogy()
    ax.legend(frameon=False)
    ax.set_xlabel("Number of Epochs")
    # ax.set_yticks([0.01, 0.05, 0.1, 0.5])
    ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.savefig("/work/bb1070/b382177/mie/icon/24-07-2023/figs/opt_epochs_x2.png", bbox_inches="tight")
plt.show()
# Out:
# time: 2.12 s (started: 2023-07-24 13:51:19 +02:00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(23, 7))
for col, ax in zip(y.columns, axes):
    ntest = test_y[col]
    npred = pred_y[col]
        
    corr = np.corrcoef(ntest, npred)[0,1]
    r2 = r2_score(ntest, npred)
    
    x1 = test_y[col]
    y1 = pred_y[col]    

    x1 = (mx[col] - mn[col]) * x1 + mn[col]
    y1 = (mx[col] - mn[col]) * y1 + mn[col]
        
    ax.scatter(x1, y1)
    ax.scatter(x1, x1)
    ax.set_title('%s [$R^2$=%0.3f]'%(col, r2), fontsize=20)
    ax.set_xlabel('Mie', fontsize=20)
    ax.minorticks_on()
    ax.tick_params(labelsize=18)
axes[0].set_ylabel('MLP', fontsize=20)
plt.savefig("/work/bb1070/b382177/mie/icon/24-07-2023/figs/mlp_accuracy_stats_x2.png", bbox_inches="tight")
plt.show()
# Out:
# time: 31.8 s (started: 2023-07-24 13:51:21 +02:00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(19, 6), sharey=True)
axes = axes.flatten()
for i, (col, ax) in enumerate(zip(y.columns, axes)):
    ntest = test_y[col]
    npred = pred_y[col]  
    
    x1 = test_y[col]
    y1 = pred_y[col]  
    
    x1 = (mx[col] - mn[col]) * x1 + mn[col]
    y1 = (mx[col] - mn[col]) * y1 + mn[col]
    
    corr = np.corrcoef(x1, y1)[0,1]    
    error = 100 * (y1 - x1) / x1   
    
    ax.hist(error, bins=np.arange(-20, 21, 1), density=True, color='blue')
    # ax.hist(error, bins=100, density=True)
    
    # ax.set_title('%s [R=%0.3f]'%(col, corr), fontsize=20)
    ax.set_title('%s'%(col), fontsize=20, y=0.9)
    ax.set_xlabel('Error [%]', fontsize=20)
    ax.set_ylabel('Density', fontsize=20)
    if i!=0:
        ax.set_ylabel('', fontsize=20)
        
    if i!=1:
        ax.set_xlabel('', fontsize=20)
        
    ax.minorticks_on()
    ax.set_yticks(np.arange(0, 0.45, 0.05))
    ax.tick_params(labelsize=16)
    
plt.subplots_adjust(hspace=0.01, wspace=0.05)
plt.savefig('/work/bb1070/b382177/mie/icon/24-07-2023/figs/mlp_error_ana_x2.png', bbox_inches='tight')
plt.show()
# Out:
# time: 1.35 s (started: 2023-07-24 13:51:53 +02:00)

# %%
model.save('/work/bb1070/b382177/mie/icon/24-07-2023/model/model_24_07_2023_x2.h5')
# Out:
# time: 109 ms (started: 2023-07-24 13:51:54 +02:00)

# %%
lmodel = tf.keras.models.load_model('/work/bb1070/b382177/mie/icon/24-07-2023/model/model_24_07_2023_x2.h5')
# Out:
# time: 162 ms (started: 2023-07-24 13:51:54 +02:00)
